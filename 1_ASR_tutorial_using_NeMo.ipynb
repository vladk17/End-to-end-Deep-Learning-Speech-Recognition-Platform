# %% [markdown]
# <a href="https://colab.research.google.com/github/vladk17/End-to-end-Deep-Learning-Speech-Recognition-Platform/blob/master/1_ASR_tutorial_using_NeMo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
You can run either this notebook locally (if you have all the dependencies and a GPU) or on Google Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
"""
# If you're using Google Colab and not running locally, run this cell.
# !pip install wget
# !apt-get install sox
# !pip install git+https://github.com/NVIDIA/apex.git

# !pip install unidecode

# !mkdir configs
# !wget -P configs/ https://raw.githubusercontent.com/NVIDIA/NeMo/master/examples/asr/configs/jasper_an4.yaml
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=1a89db5ae1c6098696ef2225451c20bbf1aeb28fd33c6973d1c99f8780f1fc34
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 16 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,715 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.3 [184 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.3 [68.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2-3ubuntu0.18.04.1 [10.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-base amd64 14.4.2-3ubuntu0.18.04.1 [32.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 sox amd64 14.4.2-3ubuntu0.18.04.1 [101 kB]
# Fetched 760 kB in 1s (635 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 145155 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Collecting git+https://github.com/NVIDIA/apex.git
#   Cloning https://github.com/NVIDIA/apex.git to /tmp/pip-req-build-uv72yl92
#   Running command git clone -q https://github.com/NVIDIA/apex.git /tmp/pip-req-build-uv72yl92
# Building wheels for collected packages: apex
#   Building wheel for apex (setup.py) ... done
#   Created wheel for apex: filename=apex-0.1-cp36-none-any.whl size=139502 sha256=54ae01cd110e35d9f12ba9ee45f0142b1ba84c6127c5b6e89dff4c27882d7d2d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vtontdm7/wheels/20/ef/9d/1967e1ee0ae20e7dc8e41ab7208017893b0a026243189508a3
# Successfully built apex
# Installing collected packages: apex
# Successfully installed apex-0.1
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 5.0MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.1.1
# --2020-02-06 03:51:41--  https://raw.githubusercontent.com/NVIDIA/NeMo/master/examples/asr/configs/jasper_an4.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1978 (1.9K) [text/plain]
# Saving to: ‘configs/jasper_an4.yaml’
#
# jasper_an4.yaml     100%[===================>]   1.93K  --.-KB/s    in 0s
#
# 2020-02-06 03:51:41 (56.9 MB/s) - ‘configs/jasper_an4.yaml’ saved [1978/1978]

# %%
# !pip install nemo-toolkit
# !pip install nemo-asr
# Out:
# Collecting nemo-toolkit
#   Downloading https://files.pythonhosted.org/packages/94/58/8deb4ae18fdebeb9481aa6a84071f7fa565388a69188bdb4bacd9f2c1556/nemo_toolkit-0.9.0-py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 3.7MB/s
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/35/f1/5843425495765c8c2dd0784a851a93ef204d314fc87bcc2bbb9f662a3ad1/tensorboardX-2.0-py2.py3-none-any.whl (195kB)
#      |████████████████████████████████| 204kB 14.3MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit) (0.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit) (0.25.3)
# Collecting onnx
#   Downloading https://files.pythonhosted.org/packages/f5/f4/e126b60d109ad1e80020071484b935980b7cce1e4796073aab086a2d6902/onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8MB)
#      |████████████████████████████████| 4.8MB 20.8MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit) (1.4.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit) (3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX->nemo-toolkit) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX->nemo-toolkit) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX->nemo-toolkit) (1.17.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->nemo-toolkit) (6.2.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->nemo-toolkit) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nemo-toolkit) (2018.9)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit) (3.6.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX->nemo-toolkit) (45.1.0)
# Installing collected packages: tensorboardX, onnx, nemo-toolkit
# Successfully installed nemo-toolkit-0.9.0 onnx-1.6.0 tensorboardX-2.0
# Collecting nemo-asr
#   Downloading https://files.pythonhosted.org/packages/70/39/6fad2fc5d56ca74e10fc2974b38427551d7410f5fe6c1428515b1ccc7bf9/nemo_asr-0.9.0-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 2.7MB/s
# Collecting marshmallow
#   Downloading https://files.pythonhosted.org/packages/0d/f5/8a5d36e0a0a7000bab80200f599868543b9c8259c75941446bde1bf6ed83/marshmallow-3.4.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 6.1MB/s
# Collecting sox
#   Downloading https://files.pythonhosted.org/packages/60/a0/5bee540554af8376e0313e462629d95bf2f2bc3c8cb60697aa01254e6cf5/sox-1.3.7-py2.py3-none-any.whl
# Collecting soundfile
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Requirement already satisfied: unidecode in /usr/local/lib/python3.6/dist-packages (from nemo-asr) (1.1.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.6/dist-packages (from nemo-asr) (2.1.0)
# Collecting torch-stft
#   Downloading https://files.pythonhosted.org/packages/9a/53/8a0114930b53459bdc6b090515636bbba7e080905284fb83c995a29eb709/torch_stft-0.1.4-py3-none-any.whl
# Collecting ruamel.yaml
#   Downloading https://files.pythonhosted.org/packages/7c/34/a6653548900805dbd4e4fa8c233fe3af6e89069d8ec1185ccf947881ac58/ruamel.yaml-0.16.7-py2.py3-none-any.whl (123kB)
#      |████████████████████████████████| 133kB 16.0MB/s
# Collecting kaldi-io
#   Downloading https://files.pythonhosted.org/packages/1c/65/3a2a0581f973f2dd96165937fab1d008e91943a97d01f570f25965c762aa/kaldi_io-0.9.1-py3-none-any.whl
# Requirement already satisfied: nemo-toolkit in /usr/local/lib/python3.6/dist-packages (from nemo-asr) (0.9.0)
# Collecting num2words
#   Downloading https://files.pythonhosted.org/packages/eb/a2/ea800689730732e27711c41beed4b2a129b34974435bdc450377ec407738/num2words-0.5.10-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 15.4MB/s
# Requirement already satisfied: librosa in /usr/local/lib/python3.6/dist-packages (from nemo-asr) (0.6.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile->nemo-asr) (1.13.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch-stft->nemo-asr) (1.17.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch-stft->nemo-asr) (1.4.1)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/53/77/4bcd63f362bcb6c8f4f06253c11f9772f64189bf08cf3f40c5ccbda9e561/ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548kB)
#      |████████████████████████████████| 552kB 64.5MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (0.5.0)
# Requirement already satisfied: onnx in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (1.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (0.25.3)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (2.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (3.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit->nemo-asr) (1.4.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/dist-packages (from num2words->nemo-asr) (0.6.2)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (0.22.1)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (1.12.0)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (0.14.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (2.1.8)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (4.4.1)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from librosa->nemo-asr) (0.47.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile->nemo-asr) (2.19)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->nemo-toolkit->nemo-asr) (6.2.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit->nemo-asr) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit->nemo-asr) (3.6.6)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->nemo-toolkit->nemo-asr) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nemo-toolkit->nemo-asr) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa->nemo-asr) (45.1.0)
# Requirement already satisfied: llvmlite>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa->nemo-asr) (0.31.0)
# Installing collected packages: marshmallow, sox, soundfile, torch-stft, ruamel.yaml.clib, ruamel.yaml, kaldi-io, num2words, nemo-asr
# Successfully installed kaldi-io-0.9.1 marshmallow-3.4.0 nemo-asr-0.9.0 num2words-0.5.10 ruamel.yaml-0.16.7 ruamel.yaml.clib-0.2.0 soundfile-0.10.3.post1 sox-1.3.7 torch-stft-0.1.4

# %% [markdown]
# # Introduction to End-To-End Automatic Speech Recognition
#
# This notebook contains a basic tutorial of Automatic Speech Recognition (ASR) concepts, introduced with code snippets using the [NeMo framework](https://github.com/NVIDIA/NeMo).
# We will first introduce the basics of the main concepts behind speech recognition, then explore concrete examples of what the data looks like and walk through putting together a simple end-to-end ASR pipeline.
#
# We assume that you are familiar with general machine learning concepts and can follow Python code, and we'll be using the [AN4 dataset from CMU](http://www.speech.cs.cmu.edu/databases/an4/) (with processing using `sox`).

# %% [markdown]
# ## Conceptual Overview: What is ASR?
#
# ASR, or **Automatic Speech Recognition**, refers to the problem of getting a program to automatically transcribe spoken language (speech-to-text). Our goal is usually to have a model that minimizes the **Word Error Rate (WER)** metric when transcribing speech input. In other words, given some audio file (e.g. a WAV file) containing speech, how do we transform this into the corresponding text with as few errors as possible?
#
# Traditional speech recognition takes a generative approach, modeling the full pipeline of how speech sounds are produced: from a **language model** that encapsulates likely orderings of words (e.g. an n-gram model), to a **pronunciation model** for each word in the vocabulary (e.g. a pronunciation table), to an **acoustic model** that translates the pronunciations to audio waveforms (e.g. a Gaussian Mixture Model), and so on.
#
# Then, if we receive some spoken input, our goal would be to find the most likely sequence of text that would result in the given audio according to our pipeline of models. Overall, with traditional speech recognition, we try to model `Pr(audio|transcript)*Pr(transcript)`, and take the argmax of this over possible transcripts.
#
# Over time, neural nets advanced to the point where each component of the traditional speech recognition model could be replaced by a neural model that had better performance and that had a greater potential for generalization. For example, we could replace an n-gram model with a neural language model, and replace a pronunciation table with a neural pronunciation model, and so on. However, each of these neural models need to be trained individually on different tasks, and errors in any model in the pipeline could throw off the whole prediction.
#
# Thus, we can see the appeal of **end-to-end ASR architectures**--discriminative models that simply take an audio input and give a textual output, and in which all components are trained together towards the same goal. A much easier pipeline to handle!

# %% [markdown]
# ### End-To-End ASR
#
# With an end-to-end model, we want to directly learn `Pr(transcript|audio)` in order to predict the transcripts from the original audio. Since we are dealing with sequential information--audio data over time that corresponds to a sequence of letters--RNNs are the obvious choice. But now we have a pressing problem to deal with: since our input sequence (number of audio timesteps) is not the same length as our desired output (transcript length), how do we match each time step from the audio data to the correct output characters?
#
# Earlier speech recognition approaches relied on **temporally-aligned data**, in which each segment of time in an audio file was matched up to a corresponding speech sound such as a phoneme or word. However, if we would like to have the flexibility to predict letter-by-letter to prevent OOV (out of vocabulary) issues, then each time step in the data would have to be labeled with the letter sound that the speaker is making at that point in the audio file. With that information, it seems like we should simply be able to try to predict the correct letter for each time step and then collapse the repeated letters (e.g. the prediction output `LLLAAAAPPTOOOPPPP` would become `LAPTOP`). It turns out that this idea has some problems: not only does alignment make the dataset incredibly labor-intensive to label, but also, what do we do with words like "book" that contain consecutive repeated letters? Simply squashing repeated letters together would not work in that case!
#
# ![Alignment example](https://raw.githubusercontent.com/NVIDIA/NeMo/master/examples/asr/notebooks/images/alignment_example.png)
#
# Modern end-to-end approaches get around this using methods that don't require manual alignment at all, so that the input-output pairs are really just the raw audio and the transcript--no extra data or labeling required. Let's briefly go over two popular approaches that allow us to do this, Connectionist Temporal Classification (CTC) and sequence-to-sequence models with attention.
#
# #### Connectionist Temporal Classification (CTC)
#
# In normal speech recognition prediction output, we would expect to have characters such as the letters from A through Z, numbers 0 through 9, spaces ("\_"), and so on. CTC introduces a new intermediate output token called the **blank token** ("-") that is useful for getting around the alignment issue.
#
# With CTC, we still predict one token per time segment of speech, but we use the blank token to figure out where we can and can't collapse the predictions. The appearance of a blank token helps separate repeating letters that should not be collapsed. For instance, with an audio snippet segmented into `T=11` time steps, we could get predictions that look like `BOO-OOO--KK`, which would then collapse to `"BO-O-K"`, and then we would remove the blank tokens to get our final output, `BOOK`.
#
# Now, we can predict one output token per time step, then collapse and clean to get sensible output without any fear of ambiguity from repeating letters! A simple way of getting predictions like this would be to apply a bidirectional RNN to the audio input, apply softmax over each time step's output, and then take the token with the highest probability. The method of always taking the best token at each time step is called **greedy decoding, or max decoding**.
#
# To calculate our loss for backprop, we would like to know the log probability of the model producing the correct transcript, `log(Pr(transcript|audio))`. We can get the log probability of a single intermediate output sequence (e.g. `BOO-OOO--KK`) by summing over the log probabilities we get from each token's softmax value, but note that the resulting sum is different from the log probability of the transcript itself (`BOOK`). This is because there are multiple possible output sequences of the same length that can be collapsed to get the same transcript (e.g. `BBO--OO-KKK` also results in `BOOK`), and so we need to **marginalize over every valid sequence of length `T` that collapses to the transcript**.
#
# Therefore, to get our transcript's log probability given our audio input, we must sum the log probabilities of every sequence of length `T` that collapses to the transcript (e.g. `log(Pr(output: "BOOK"|audio)) = log(Pr(BOO-OOO--KK|audio)) + log(Pr(BBO--OO-KKK|audio)) + ...`). In practice, we can use a dynamic programming approach to calculate this, accumulating our log probabilities over different "paths" through the softmax outputs at each time step.
#
# If you would like a more in-depth explanation of how CTC works, or how we can improve our results by using a modified beam search algorithm, feel free to check out the Further Reading section at the end of this notebook for more resources.
#
# #### Sequence-to-Sequence with Attention
#
# One problem with CTC is that predictions at different time steps are conditionally independent, which is an issue because the words in a continuous utterance tend to be related to each other in some sensible way. With this conditional independence assumption, we can't learn a language model that can represent such dependencies, though we can add a language model on top of the CTC output to mitigate this to some degree.
#
# A popular alternative is to use a sequence-to-sequence model with attention. A typical seq2seq model for ASR consists of some sort of **bidirectional RNN encoder** that consumes the audio sequence timestep-by-timestep, and where the outputs are then passed to an **attention-based decoder**. Each prediction from the decoder is based on attending to some parts of the entire encoded input, as well as the previously outputted tokens.
#
# The outputs of the decoder can be anything from word pieces to phonemes to letters, and since predictions are not directly tied to time steps of the input, we can just continue producing tokens one-by-one until an end token is given (or we reach a specified max output length). This way, we do not need to deal with audio alignment, and our predicted transcript is just the sequence of outputs given by our decoder.
#
# Now that we have an idea of what some popular end-to-end ASR models look like, let's take a look at the audio data we'll be working with for our example.

# %% [markdown]
# ## Taking a Look at Our Data (AN4)
#
# The AN4 dataset, also known as the Alphanumeric dataset, was collected and published by Carnegie Mellon University. It consists of recordings of people spelling out addresses, names, telephone numbers, etc., one letter or number at a time, as well as their corresponding transcripts. We choose to use AN4 for this tutorial because it is relatively small, with 948 training and 130 test utterances, and so it trains quickly.
#
# Before we get started, let's download and prepare the dataset. The utterances are available as `.sph` files, so we will need to convert them to `.wav` for later processing. Please make sure you have [Sox](http://sox.sourceforge.net/) installed for this step (see the "Downloads" section of the main page).

# %%
# This is where the an4/ directory will be placed.
# Change this if you don't want the data to be extracted in the current directory.
data_dir = '.'

# %%
import glob
import os
import subprocess
import tarfile
import wget

# Download the dataset. This will take a few moments...
print("******")
if not os.path.exists(data_dir + '/an4_sphere.tar.gz'):
    an4_url = 'http://www.speech.cs.cmu.edu/databases/an4/an4_sphere.tar.gz'
    an4_path = wget.download(an4_url, data_dir)
    print(f"Dataset downloaded at: {an4_path}")
else:
    print("Tarfile already exists.")
    an4_path = data_dir + '/an4_sphere.tar.gz'

# Untar and convert .sph to .wav (using sox)
tar = tarfile.open(an4_path)
tar.extractall(path=data_dir)

print("Converting .sph to .wav...")
sph_list = glob.glob(data_dir + '/an4/**/*.sph', recursive=True)
for sph_path in sph_list:
    wav_path = sph_path[:-4] + '.wav'
    cmd = ["sox", sph_path, wav_path]
    subprocess.run(cmd)
print("Finished conversion.\n******")
# Out:
# ******
# Dataset downloaded at: ./an4_sphere.tar.gz
# Converting .sph to .wav...
# Finished conversion.
# ******

# %% [markdown]
# You should now have a folder called `an4` that contains `etc/an4_train.transcription`, `etc/an4_test.transcription`, audio files in `wav/an4_clstk` and `wav/an4test_clstk`, along with some other files we will not need.
#
# Now we can load and take a look at the data. As an example, file `cen2-mgah-b.wav` is a 2.6 second-long audio recording of a man saying the letters "G L E N N" one-by-one (feel free to check this out by listening to `./an4/wav/an4_clstk/mgah/cen2-mgah-b.wav`). In an ASR task, the WAV file would be our input, and "G L E N N" would be our desired output.
#
# Let's plot the waveform, which is simply a line plot of the sequence of values that we read from the file. This is a format of viewing audio that you are likely to be familiar with seeing in many audio editors and visualizers:

# %%
# %matplotlib inline
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Plot our example audio file's waveform
example_file = data_dir + '/an4/wav/an4_clstk/mgah/cen2-mgah-b.wav'
audio, sample_rate = librosa.load(example_file)

plt.rcParams['figure.figsize'] = (15,7)
plt.title('Waveform of Audio Example')
plt.ylabel('Amplitude')

_ = librosa.display.waveplot(audio)

# %% [markdown]
# We can see the activity in the waveform that corresponds to each letter in the audio, as our speaker here enunciates quite clearly!
# You can kind of tell that each spoken letter has a different "shape," and it's interesting to note that last two blobs look relatively similar, which is expected because they are both the letter "N."
#
# ### Spectrograms and Mel Spectrograms
#
# However, since audio information is more useful in the context of frequencies of sound over time, we can get a better representation than this raw sequence of 57,330 values.
# We can apply a [Fourier Transform](https://en.wikipedia.org/wiki/Fourier_transform) on our audio signal to get something more useful: a **spectrogram**, which is a representation of the energy levels (i.e. amplitude, or "loudness") of each frequency (i.e. pitch) of the signal over the duration of the file.
# A spectrogram (which can be viewed as a heat map) is a good way of seeing how the *strengths of various frequencies in the audio vary over time*, and is obtained by breaking up the signal into smaller, usually overlapping chunks and performing a Short-Time Fourier Transform (STFT) on each.
#
# Let's examine what the spectrogram of our sample looks like.

# %%
# Get spectrogram using Librosa's Short-Time Fourier Transform (stft)
spec = np.abs(librosa.stft(audio))
spec_db = librosa.amplitude_to_db(spec, ref=np.max)  # Decibels

# Use log scale to view frequencies
librosa.display.specshow(spec_db, y_axis='log', x_axis='time')
plt.colorbar()
plt.title('Audio Spectrogram');

# %% [markdown]
# Again, we are able to see each letter being pronounced, and that the last two blobs that correspond to the "N"s are pretty similar-looking. But how do we interpret these shapes and colors? Just as in the waveform plot before, we see time passing on the x-axis (all 2.6s of audio). But now, the y-axis represents different frequencies (on a log scale), and *the color on the plot shows the strength of a frequency at a particular point in time*.
#
# We're still not done yet, as we can make one more potentially useful tweak: using the **Mel Spectrogram** instead of the normal spectrogram. This is simply a change in the frequency scale that we use from linear (or logarithmic) to the mel scale, which is "a perceptual scale of pitches judged by listeners to be equal in distance from one another" (from [Wikipedia](https://en.wikipedia.org/wiki/Mel_scale)).
#
# In other words, it's a transformation of the frequencies to be more aligned to what humans perceive; a change of +1000Hz from 2000Hz->3000Hz sounds like a larger difference to us than 9000Hz->10000Hz does, so the mel scale normalizes this such that equal distances sound like equal differences to the human ear. Intuitively, we use the mel spectrogram because in this case we are processing and transcribing human speech, such that transforming the scale to better match what we hear is a useful procedure.

# %%
# Plot the mel spectrogram of our sample
mel_spec = librosa.feature.melspectrogram(audio, sr=sample_rate)
mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

librosa.display.specshow(
    mel_spec_db, x_axis='time', y_axis='mel')
plt.colorbar()
plt.title('Mel Spectrogram');

# %% [markdown]
# ## Building a Simple ASR Pipeline in NeMo
#
# Now that we have an idea of what the audio data looks like, we can start building our end-to-end ASR pipeline!
#
# We'll be using the **Neural Modules (NeMo) toolkit** for this part, so if you haven't already, you should download and install NeMo and its dependencies. To do so, just follow the directions on the [GitHub page](https://github.com/NVIDIA/NeMo), or in the [documentation](https://nvidia.github.io/NeMo/).
#
# NeMo lets us easily hook together the components (modules) of our model, such as the data layer, intermediate layers, and various losses, without worrying too much about implementation details of individual parts or connections between modules. If you're curious, you can read more about NeMo and how it works in the documentation pages linked above.

# %%
# !git clone https://github.com/NVIDIA/NeMo.git
# Out:
# Cloning into 'NeMo'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 15327 (delta 100), reused 121 (delta 62), pack-reused 15138
# Receiving objects: 100% (15327/15327), 31.98 MiB | 24.10 MiB/s, done.
# Resolving deltas: 100% (10368/10368), done.

# %%
# !pip install NeMo/.
# Out:
# Processing ./NeMo
# Requirement already satisfied: onnx in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (1.6.0)
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/3b/13/1ac0397bcffb30d03af3de80eae9b960883d2e43e3a562423260948390f5/onnxruntime-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 4.6MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (0.25.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (2.6.1)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (2.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (1.15.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (0.5.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.6/dist-packages (from nemo-toolkit==0.9.0) (1.11.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit==0.9.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit==0.9.0) (1.17.5)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit==0.9.0) (3.6.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from onnx->nemo-toolkit==0.9.0) (1.12.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nemo-toolkit==0.9.0) (2018.9)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (3.1.1)
# Requirement already satisfied: grpcio>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (1.15.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (45.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (0.16.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (0.9.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->nemo-toolkit==0.9.0) (0.34.2)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->nemo-toolkit==0.9.0) (6.2.2)
# Building wheels for collected packages: nemo-toolkit
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-0.9.0-cp36-none-any.whl size=8180843 sha256=31736c4bfd2d656a6e0b840fe415c584461c5aacf4d8769df754b409e818e9dd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-faxfr_f5/wheels/06/f2/7d/c3e592e91adf0866f68440546bb5a4b8dcb9bd035e297bdce8
# Successfully built nemo-toolkit
# Installing collected packages: onnxruntime, nemo-toolkit
#   Found existing installation: nemo-toolkit 0.9.0
#     Uninstalling nemo-toolkit-0.9.0:
#       Successfully uninstalled nemo-toolkit-0.9.0
# Successfully installed nemo-toolkit-0.9.0 onnxruntime-1.1.1

# %%
# !pip install frozendict
# Out:
# Collecting frozendict
#   Downloading https://files.pythonhosted.org/packages/4e/55/a12ded2c426a4d2bee73f88304c9c08ebbdbadb82569ebdd6a0c007cfd08/frozendict-1.2.tar.gz
# Building wheels for collected packages: frozendict
#   Building wheel for frozendict (setup.py) ... done
#   Created wheel for frozendict: filename=frozendict-1.2-cp36-none-any.whl size=3149 sha256=13f87a07d85789c19e117bf0f2e549a2c20c454ef1cde7a3636137c07a6cf448
#   Stored in directory: /root/.cache/pip/wheels/6c/6c/e9/534386165bd12cf1885582c75eb6d0ffcb321b65c23fe0f834
# Successfully built frozendict
# Installing collected packages: frozendict
# Successfully installed frozendict-1.2

# %%
# !pwd
# Out:
# /content

# %%
# Install the ASR collection from collections/nemo_asr
# !apt-get install libsndfile1
# !pip install NeMo/nemo/collections/asr/.

# Install the NLP collection from collections/nemo_nlp
# !pip install NeMo/nemo/collections/nlp/.

# Install the TTS collection from collections/nemo_tts
# !pip install NeMo/nemo/collections/tts/.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
# NeMo's "core" package
import nemo
# NeMo's ASR collection
import nemo.collections.asr as nemo_asr
# Out:
# /usr/local/lib/python3.6/dist-packages/nemo/collections/asr/audio_preprocessing.py:45: UserWarning: Could not import torchaudio. Some features might not work.
#   warnings.warn('Could not import torchaudio. Some features might not work.')

# %% [markdown]
# ### Creating Data Manifests
#
# The first thing we need to do now is to create manifests for our training and evaluation data, which will contain the metadata of our audio files. NeMo data layers take in a standardized manifest format where each line corresponds to one sample of audio, such that the number of lines in a manifest is equal to the number of samples that are represented by that manifest. A line must contain the path to an audio file, the corresponding transcript (or path to a transcript file), and the duration of the audio sample.
#
# Here's an example of what one line in a NeMo-compatible manifest might look like:
# ```
# {"audio_filepath": "path/to/audio.wav", "duration": 3.45, "text": "this is a nemo tutorial"}
# ```
#
# We can build our training and evaluation manifests using `an4/etc/an4_train.transcription` and `an4/etc/an4_test.transcription`, which have lines containing transcripts and their corresponding audio file IDs:
# ```
# ...
# <s> P I T T S B U R G H </s> (cen5-fash-b)
# <s> TWO SIX EIGHT FOUR FOUR ONE EIGHT </s> (cen7-fash-b)
# ...
# ```

# %%
# --- Building Manifest Files --- #
import json

# Function to build a manifest
def build_manifest(transcripts_path, manifest_path, wav_path):
    with open(transcripts_path, 'r') as fin:
        with open(manifest_path, 'w') as fout:
            for line in fin:
                # Lines look like this:
                # <s> transcript </s> (fileID)
                transcript = line[: line.find('(')-1].lower()
                transcript = transcript.replace('<s>', '').replace('</s>', '')
                transcript = transcript.strip()

                file_id = line[line.find('(')+1 : -2]  # e.g. "cen4-fash-b"
                audio_path = os.path.join(
                    data_dir, wav_path,
                    file_id[file_id.find('-')+1 : file_id.rfind('-')],
                    file_id + '.wav')

                duration = librosa.core.get_duration(filename=audio_path)

                # Write the metadata to the manifest
                metadata = {
                    "audio_filepath": audio_path,
                    "duration": duration,
                    "text": transcript
                }
                json.dump(metadata, fout)
                fout.write('\n')
                
# Building Manifests
print("******")
train_transcripts = data_dir + '/an4/etc/an4_train.transcription'
train_manifest = data_dir + '/an4/train_manifest.json'
build_manifest(train_transcripts, train_manifest, 'an4/wav/an4_clstk')
print("Training manifest created.")

test_transcripts = data_dir + '/an4/etc/an4_test.transcription'
test_manifest = data_dir + '/an4/test_manifest.json'
build_manifest(test_transcripts, test_manifest, 'an4/wav/an4test_clstk')
print("Test manifest created.")
print("******")
# Out:
# ******
# Training manifest created.
# Test manifest created.
# ******

# %% [markdown]
# ### Building Training and Evaluation DAGs
#
# Let's take a look at the model that we will be building, and how we specify its parameters.
#
# #### The Jasper Model
#
# We will be putting together a small [Jasper (Just Another SPeech Recognizer) model](https://arxiv.org/abs/1904.03288).
# In brief, Jasper architectures consist of a repeated block structure that utilizes 1D convolutions.
# In a Jasper_KxR model, `R` sub-blocks (consisting of a 1D convolution, batch norm, ReLU, and dropout) are grouped into a single block, which is then repeated `K` times.
# We also have a one extra block at the beginning and a few more at the end that are invariant of `K` and `R`, and we use CTC loss.
#
# A Jasper model looks like roughly this:
#
# ![Jasper with CTC](https://raw.githubusercontent.com/NVIDIA/NeMo/master/docs/sources/source/asr/jasper.png)
#
# #### Specifying Our Model with a YAML File
#
# For this tutorial, we'll build a *Jasper_4x1 model*, with `K=4` blocks of single (`R=1`) sub-blocks and a *greedy CTC decoder*, using the configuration found in `./configs/jasper_an4.yaml`.
#
# If we open up this config file, we find that there is an entry labeled `JasperEncoder`, with a field called `jasper` that contains a list with multiple entries. Each of the members in this list specifies one block in our model, and looks something like this:
# ```
# - filters: 256
#   repeat: 1
#   kernel: [11]
#   stride: [2]
#   dilation: [1]
#   dropout: 0.2
#   residual: false
# ```
# The first member of the list corresponds to the first block in the Jasper architecture diagram, which appears regardless of `K` and `R`.
# Next, we have four entries that correspond to the `K=4` blocks, and each has `repeat: 1` since we are using `R=1`.
# These are followed by two more entries for the blocks that appear at the end of our Jasper model before the CTC loss.
#
# There are also some entries at the top of the file that specify that we should be shuffling our training data but not our evaluation data (see `AudioToTextDataLayer`), and some specifications for preprocessing and converting the audio data (in `AudioToMelSpectrogramPreprocessor`).
#
# Using a YAML config such as this is helpful for getting a quick and human-readable overview of what your architecture looks like, and allows you to swap out model and run configurations easily.
#
# #### Building Training and Evaluation DAGs with NeMo
#
# Building a model using NeMo consists of (1) instantiating the neural modules we need and (2) specifying the DAG by linking them together.
#
# Let's start by loading the config.

# %%
# --- Loading Config --- #
from ruamel.yaml import YAML

# Parse config and pass to model building function
config_path = './configs/jasper_an4.yaml'
yaml = YAML(typ='safe')
with open(config_path) as f:
    params = yaml.load(f)
    print("******\nLoaded config file.\n******")

labels = params['labels']  # Vocab of tokens
sample_rate = params['sample_rate']
# Out:
# ******
# Loaded config file.
# ******

# %% [markdown]
# In NeMo, **the training and inference pipelines are managed by a `NeuralModuleFactory`**, which takes care of checkpointing, callbacks, and logs, along with other details in training and inference. We set its `log_dir` argument to specify where our model logs and outputs will be written, and can set other training and inference settings in its constructor. For instance, if we were **resuming training from a checkpoint**, we would set the argument `checkpoint_dir=<path_to_checkpoint>`.

# %%
# Create our NeuralModuleFactory, which will oversee the neural modules.
neural_factory = nemo.core.NeuralModuleFactory(
    log_dir=data_dir+'/an4_tutorial/')

logger = neural_factory.logger
# Out:
# [NeMo W 2020-02-06 03:58:03 deprecated:66] Function ``_get_trainer`` is deprecated. It is going to be removed in the future version.
# [NeMo W 2020-02-06 03:58:03 deprecated:66] Function ``logger`` is deprecated. It is going to be removed in the 0.11 version. Please use ``nemo.logging instead``

# %% [markdown]
# Note that if you would like your pipeline to support running on CPU, you should
# instead add these imports and then add an additional 'placement' argument:
#
# ```python
# import torch
# from nemo.core import DeviceType
#
# neural_factory = nemo.core.NeuralModuleFactory(
#     log_dir=data_dir+'/an4_tutorial/',
#     placement=(DeviceType.GPU if torch.cuda.is_available() else DeviceType.CPU)
#     )
# ```
#
# Now that we have the configurations and our neural module factory, we can specify our neural modules and instantiate them.

# %%
# --- Instantiate Neural Modules --- #

# Create training and test data layers (which load data) and data preprocessor
data_layer_train = nemo_asr.AudioToTextDataLayer(
    manifest_filepath=train_manifest,
    sample_rate=sample_rate,
    labels=labels,
    batch_size=32,
    **params['AudioToTextDataLayer']['train'])  # Training datalayer

data_layer_test = nemo_asr.AudioToTextDataLayer(
    manifest_filepath=test_manifest,
    sample_rate=sample_rate,
    labels=labels,
    batch_size=32,
    **params['AudioToTextDataLayer']['eval'])   # Eval datalayer

data_preprocessor = nemo_asr.AudioToMelSpectrogramPreprocessor(
    sample_rate=sample_rate,
    **params['AudioToMelSpectrogramPreprocessor'])

# Create the Jasper_4x1 encoder as specified, and a CTC decoder
encoder = nemo_asr.JasperEncoder(**params['JasperEncoder'])

decoder = nemo_asr.JasperDecoderForCTC(
    feat_in=params['JasperEncoder']['jasper'][-1]['filters'],
    num_classes=len(labels))

ctc_loss = nemo_asr.CTCLossNM(num_classes=len(labels))
greedy_decoder = nemo_asr.GreedyCTCDecoder()
# Out:
# [NeMo I 2020-02-06 03:58:30 collections:132] Filtered duration for loading collection is 0.000000.
# [NeMo I 2020-02-06 03:58:30 collections:132] Filtered duration for loading collection is 0.000000.
# [NeMo I 2020-02-06 03:58:30 features:144] PADDING: 16
# [NeMo I 2020-02-06 03:58:30 features:152] STFT using conv

# %% [markdown]
# The next step is to assemble our training DAG by specifying the inputs to each neural module.

# %%
# --- Assemble Training DAG --- #
audio_signal, audio_signal_len, transcript, transcript_len = data_layer_train()

processed_signal, processed_signal_len = data_preprocessor(
    input_signal=audio_signal,
    length=audio_signal_len)

encoded, encoded_len = encoder(
    audio_signal=processed_signal,
    length=processed_signal_len)

log_probs = decoder(encoder_output=encoded)
preds = greedy_decoder(log_probs=log_probs)  # Training predictions
loss = ctc_loss(
    log_probs=log_probs,
    targets=transcript,
    input_length=encoded_len,
    target_length=transcript_len)

# %% [markdown]
# We would like to be able to evaluate our model on the test set, as well, so let's set up the evaluation DAG.
#
# Our **evaluation DAG will reuse most of the parts of the training DAG with the exception of the data layer**, since we are loading the evaluation data from a different file but evaluating on the same model. Note that if we were using data augmentation in training, we would also leave that out in the evaluation DAG.

# %%
# --- Assemble Validation DAG --- #
(audio_signal_test, audio_len_test,
 transcript_test, transcript_len_test) = data_layer_test()

processed_signal_test, processed_len_test = data_preprocessor(
    input_signal=audio_signal_test,
    length=audio_len_test)

encoded_test, encoded_len_test = encoder(
    audio_signal=processed_signal_test,
    length=processed_len_test)

log_probs_test = decoder(encoder_output=encoded_test)
preds_test = greedy_decoder(log_probs=log_probs_test)  # Test predictions
loss_test = ctc_loss(
    log_probs=log_probs_test,
    targets=transcript_test,
    input_length=encoded_len_test,
    target_length=transcript_len_test)

# %% [markdown]
# ### Running the Model
#
# We would like to be able to monitor our model while it's training, so we use **callbacks**. In general, *callbacks are functions that are called at specific intervals over the course of training or inference*, such as at the start or end of every *n* iterations, epochs, etc. The callbacks we'll be using for this are the `SimpleLossLoggerCallback`, which reports the training loss (or another metric of your choosing, such as WER for ASR tasks), and the `EvaluatorCallback`, which regularly evaluates the model on the test set. Both of these callbacks require you to pass in the tensors to be evaluated--these would be the final outputs of the training and eval DAGs above.
#
# Another useful callback is the `CheckpointCallback`, for saving checkpoints at set intervals. We create one here just to demonstrate how it works.

# %%
# --- Create Callbacks --- #

# We use these imports to pass to callbacks more complex functions to perform.
from nemo.collections.asr.helpers import monitor_asr_train_progress, \
    process_evaluation_batch, process_evaluation_epoch
from functools import partial

train_callback = nemo.core.SimpleLossLoggerCallback(
    # Notice that we pass in loss, predictions, and the transcript info.
    # Of course we would like to see our training loss, but we need the
    # other arguments to calculate the WER.
    tensors=[loss, preds, transcript, transcript_len],
    # The print_func defines what gets printed.
    print_func=partial(
        monitor_asr_train_progress,
        labels=labels,
        # logger=logger
        )
    )

# We can create as many evaluation DAGs and callbacks as we want,
# which is useful in the case of having more than one evaluation dataset.
# In this case, we only have one.
eval_callback = nemo.core.EvaluatorCallback(
    eval_tensors=[loss_test, preds_test, transcript_test, transcript_len_test],
    user_iter_callback=partial(
        process_evaluation_batch, labels=labels),
    user_epochs_done_callback=partial(
        process_evaluation_epoch, 
        # logger=logger
        ),
    eval_step=500  # How often we evaluate the model on the test set
    )

checkpoint_saver_callback = nemo.core.CheckpointCallback(
    folder=data_dir+'/an4_checkpoints',
    step_freq=1000  # How often checkpoints are saved
    )

if not os.path.exists(data_dir+'/an4_checkpoints'):
    os.makedirs(data_dir+'/an4_checkpoints')

# %% [markdown]
# Now that we have our model and callbacks set up, **how do we run it**?
#
# Once we create our neural factory and the callbacks for the information that we want to see, we can **start training** by simply calling the train function on the tensors we want to optimize and our callbacks!

# %%
# --- Start Training! --- #
neural_factory.train(
    tensors_to_optimize=[loss],
    callbacks=[train_callback, eval_callback, checkpoint_saver_callback],
    optimizer='novograd',
    optimization_params={
        "num_epochs": 100, "lr": 0.01, "weight_decay": 1e-4
    })

# Training for 100 epochs will take a little while, depending on your machine.
# It should take about 20 minutes on Google Colab.
# At the end of 100 epochs, your evaluation WER should be around 20-25%.
# Out:
# [NeMo I 2020-02-06 03:59:15 callbacks:161] Starting .....
# [NeMo I 2020-02-06 03:59:15 callbacks:327] Found 2 modules with weights:
# [NeMo I 2020-02-06 03:59:15 callbacks:329] JasperEncoder
# [NeMo I 2020-02-06 03:59:15 callbacks:329] JasperDecoderForCTC
# [NeMo I 2020-02-06 03:59:15 callbacks:330] Total model parameters: 5771293
# [NeMo I 2020-02-06 03:59:15 callbacks:285] Restoring checkpoint from folder ./an4_checkpoints ...
# [NeMo W 2020-02-06 03:59:15 callbacks:302] For module JasperDecoderForCTC, no file matches  in ./an4_checkpoints
# [NeMo W 2020-02-06 03:59:15 callbacks:303] Checkpoint folder ./an4_checkpoints present but did not restore
# [NeMo I 2020-02-06 03:59:15 callbacks:172] Starting epoch 0
# [NeMo I 2020-02-06 03:59:16 callbacks:196] Step: 0
# [NeMo I 2020-02-06 03:59:16 helpers:70] Loss: 741.983642578125
# [NeMo I 2020-02-06 03:59:16 helpers:71] training_batch_WER:  100.97%
# [NeMo I 2020-02-06 03:59:16 helpers:72] Prediction: kafhialailerleilmeiaedaedydipaexciayaniailbaheiaedyidcqiqfdbfyefaeieace ei aicaldliyleaianhlsleidiqaddana'xdiacaidd'malidedhacfqlacadidaibaekeifdieldiydmdaeaecdcadhdidal'ianidhiea
# [NeMo I 2020-02-06 03:59:16 helpers:73] Reference: j o h n s o n
# [NeMo I 2020-02-06 03:59:16 callbacks:211] Step time: 0.3754570484161377 seconds
# [NeMo I 2020-02-06 03:59:16 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 03:59:16 helpers:148] ==========>>>>>>Evaluation Loss: 787.503662109375
# [NeMo I 2020-02-06 03:59:16 helpers:149] ==========>>>>>>Evaluation WER:  101.94%
# [NeMo I 2020-02-06 03:59:16 callbacks:411] Evaluation time: 0.44562578201293945 seconds
# [NeMo I 2020-02-06 03:59:20 callbacks:196] Step: 25
# [NeMo I 2020-02-06 03:59:20 helpers:70] Loss: 71.62093353271484
# [NeMo I 2020-02-06 03:59:20 helpers:71] training_batch_WER:  98.45%
# [NeMo I 2020-02-06 03:59:20 helpers:72] Prediction: l
# [NeMo I 2020-02-06 03:59:20 helpers:73] Reference: r h h u f two
# [NeMo I 2020-02-06 03:59:20 callbacks:211] Step time: 0.14539027214050293 seconds
# [NeMo I 2020-02-06 03:59:21 callbacks:179] Finished epoch 0 in 5.315038204193115
# [NeMo I 2020-02-06 03:59:21 callbacks:172] Starting epoch 1
# [NeMo I 2020-02-06 03:59:24 callbacks:196] Step: 50
# [NeMo I 2020-02-06 03:59:24 helpers:70] Loss: 50.625892639160156
# [NeMo I 2020-02-06 03:59:24 helpers:71] training_batch_WER:  100.00%
# [NeMo I 2020-02-06 03:59:24 helpers:72] Prediction:
# [NeMo I 2020-02-06 03:59:24 helpers:73] Reference: yes
# [NeMo I 2020-02-06 03:59:24 callbacks:211] Step time: 0.14813804626464844 seconds
# [NeMo I 2020-02-06 03:59:25 callbacks:179] Finished epoch 1 in 4.606917142868042
# [NeMo I 2020-02-06 03:59:25 callbacks:172] Starting epoch 2
# [NeMo I 2020-02-06 03:59:28 callbacks:196] Step: 75
# [NeMo I 2020-02-06 03:59:28 helpers:70] Loss: 52.990230560302734
# [NeMo I 2020-02-06 03:59:28 helpers:71] training_batch_WER:  100.00%
# [NeMo I 2020-02-06 03:59:28 helpers:72] Prediction:  s
# [NeMo I 2020-02-06 03:59:28 helpers:73] Reference: two six eight four four one eight
# [NeMo I 2020-02-06 03:59:28 callbacks:211] Step time: 0.1484372615814209 seconds
# [NeMo I 2020-02-06 03:59:30 callbacks:179] Finished epoch 2 in 4.610405445098877
# [NeMo I 2020-02-06 03:59:30 callbacks:172] Starting epoch 3
# [NeMo I 2020-02-06 03:59:31 callbacks:196] Step: 100
# [NeMo I 2020-02-06 03:59:31 helpers:70] Loss: 35.86369705200195
# [NeMo I 2020-02-06 03:59:31 helpers:71] training_batch_WER:  96.70%
# [NeMo I 2020-02-06 03:59:31 helpers:72] Prediction:
# [NeMo I 2020-02-06 03:59:31 helpers:73] Reference: w a y n e
# [NeMo I 2020-02-06 03:59:31 callbacks:211] Step time: 0.1545102596282959 seconds
# [NeMo I 2020-02-06 03:59:34 callbacks:179] Finished epoch 3 in 4.687456369400024
# [NeMo I 2020-02-06 03:59:34 callbacks:172] Starting epoch 4
# [NeMo I 2020-02-06 03:59:35 callbacks:196] Step: 125
# [NeMo I 2020-02-06 03:59:35 helpers:70] Loss: 35.055274963378906
# [NeMo I 2020-02-06 03:59:35 helpers:71] training_batch_WER:  93.02%
# [NeMo I 2020-02-06 03:59:35 helpers:72] Prediction: e fi hi t
# [NeMo I 2020-02-06 03:59:35 helpers:73] Reference: one five three two
# [NeMo I 2020-02-06 03:59:35 callbacks:211] Step time: 0.14244723320007324 seconds
# [NeMo I 2020-02-06 03:59:39 callbacks:179] Finished epoch 4 in 4.697150945663452
# [NeMo I 2020-02-06 03:59:39 callbacks:172] Starting epoch 5
# [NeMo I 2020-02-06 03:59:39 callbacks:196] Step: 150
# [NeMo I 2020-02-06 03:59:39 helpers:70] Loss: 24.243728637695312
# [NeMo I 2020-02-06 03:59:39 helpers:71] training_batch_WER:  87.30%
# [NeMo I 2020-02-06 03:59:39 helpers:72] Prediction:     fit
# [NeMo I 2020-02-06 03:59:39 helpers:73] Reference: rubout z y t l fifty one
# [NeMo I 2020-02-06 03:59:39 callbacks:211] Step time: 0.14351701736450195 seconds
# [NeMo I 2020-02-06 03:59:43 callbacks:196] Step: 175
# [NeMo I 2020-02-06 03:59:43 helpers:70] Loss: 19.88100242614746
# [NeMo I 2020-02-06 03:59:43 helpers:71] training_batch_WER:  74.62%
# [NeMo I 2020-02-06 03:59:43 helpers:72] Prediction:    gh r sixt one
# [NeMo I 2020-02-06 03:59:43 helpers:73] Reference: d y m h r sixty one
# [NeMo I 2020-02-06 03:59:43 callbacks:211] Step time: 0.14970016479492188 seconds
# [NeMo I 2020-02-06 03:59:44 callbacks:179] Finished epoch 5 in 4.614082336425781
# [NeMo I 2020-02-06 03:59:44 callbacks:172] Starting epoch 6
# [NeMo I 2020-02-06 03:59:47 callbacks:196] Step: 200
# [NeMo I 2020-02-06 03:59:47 helpers:70] Loss: 11.8966064453125
# [NeMo I 2020-02-06 03:59:47 helpers:71] training_batch_WER:  52.94%
# [NeMo I 2020-02-06 03:59:47 helpers:72] Prediction: p r  n c e
# [NeMo I 2020-02-06 03:59:47 helpers:73] Reference: p r i n c e
# [NeMo I 2020-02-06 03:59:47 callbacks:211] Step time: 0.1537487506866455 seconds
# [NeMo I 2020-02-06 03:59:48 callbacks:179] Finished epoch 6 in 4.5951995849609375
# [NeMo I 2020-02-06 03:59:48 callbacks:172] Starting epoch 7
# [NeMo I 2020-02-06 03:59:51 callbacks:196] Step: 225
# [NeMo I 2020-02-06 03:59:51 helpers:70] Loss: 10.040414810180664
# [NeMo I 2020-02-06 03:59:51 helpers:71] training_batch_WER:  43.37%
# [NeMo I 2020-02-06 03:59:51 helpers:72] Prediction: x d vseve
# [NeMo I 2020-02-06 03:59:51 helpers:73] Reference: x e d v seven
# [NeMo I 2020-02-06 03:59:51 callbacks:211] Step time: 0.14911937713623047 seconds
# [NeMo I 2020-02-06 03:59:53 callbacks:179] Finished epoch 7 in 4.584151268005371
# [NeMo I 2020-02-06 03:59:53 callbacks:172] Starting epoch 8
# [NeMo I 2020-02-06 03:59:55 callbacks:196] Step: 250
# [NeMo I 2020-02-06 03:59:55 helpers:70] Loss: 8.86263370513916
# [NeMo I 2020-02-06 03:59:55 helpers:71] training_batch_WER:  32.98%
# [NeMo I 2020-02-06 03:59:55 helpers:72] Prediction: enter one thirty one
# [NeMo I 2020-02-06 03:59:55 helpers:73] Reference: enter one thirty one
# [NeMo I 2020-02-06 03:59:55 callbacks:211] Step time: 0.14561748504638672 seconds
# [NeMo I 2020-02-06 03:59:58 callbacks:179] Finished epoch 8 in 4.649495363235474
# [NeMo I 2020-02-06 03:59:58 callbacks:172] Starting epoch 9
# [NeMo I 2020-02-06 03:59:59 callbacks:196] Step: 275
# [NeMo I 2020-02-06 03:59:59 helpers:70] Loss: 8.57876205444336
# [NeMo I 2020-02-06 03:59:59 helpers:71] training_batch_WER:  37.36%
# [NeMo I 2020-02-06 03:59:59 helpers:72] Prediction:  o fhirte nineten sixty nine
# [NeMo I 2020-02-06 03:59:59 helpers:73] Reference: april thirtieth nineteen sixty nine
# [NeMo I 2020-02-06 03:59:59 callbacks:211] Step time: 0.15258073806762695 seconds
# [NeMo I 2020-02-06 04:00:02 callbacks:179] Finished epoch 9 in 4.596680402755737
# [NeMo I 2020-02-06 04:00:02 callbacks:172] Starting epoch 10
# [NeMo I 2020-02-06 04:00:02 callbacks:196] Step: 300
# [NeMo I 2020-02-06 04:00:02 helpers:70] Loss: 4.803613185882568
# [NeMo I 2020-02-06 04:00:02 helpers:71] training_batch_WER:  29.59%
# [NeMo I 2020-02-06 04:00:02 helpers:72] Prediction: l o n g v i e w
# [NeMo I 2020-02-06 04:00:02 helpers:73] Reference: l o n g v i e w
# [NeMo I 2020-02-06 04:00:02 callbacks:211] Step time: 0.1416454315185547 seconds
# [NeMo I 2020-02-06 04:00:06 callbacks:196] Step: 325
# [NeMo I 2020-02-06 04:00:06 helpers:70] Loss: 5.7918701171875
# [NeMo I 2020-02-06 04:00:06 helpers:71] training_batch_WER:  22.64%
# [NeMo I 2020-02-06 04:00:06 helpers:72] Prediction: enter sixy
# [NeMo I 2020-02-06 04:00:06 helpers:73] Reference: enter sixty
# [NeMo I 2020-02-06 04:00:06 callbacks:211] Step time: 0.1449286937713623 seconds
# [NeMo I 2020-02-06 04:00:07 callbacks:179] Finished epoch 10 in 4.6542088985443115
# [NeMo I 2020-02-06 04:00:07 callbacks:172] Starting epoch 11
# [NeMo I 2020-02-06 04:00:10 callbacks:196] Step: 350
# [NeMo I 2020-02-06 04:00:10 helpers:70] Loss: 4.202030181884766
# [NeMo I 2020-02-06 04:00:10 helpers:71] training_batch_WER:  21.58%
# [NeMo I 2020-02-06 04:00:10 helpers:72] Prediction: four one two five two one eh two six o
# [NeMo I 2020-02-06 04:00:10 helpers:73] Reference: four one two five two one eight two six oh
# [NeMo I 2020-02-06 04:00:10 callbacks:211] Step time: 0.1450972557067871 seconds
# [NeMo I 2020-02-06 04:00:11 callbacks:179] Finished epoch 11 in 4.617598533630371
# [NeMo I 2020-02-06 04:00:11 callbacks:172] Starting epoch 12
# [NeMo I 2020-02-06 04:00:14 callbacks:196] Step: 375
# [NeMo I 2020-02-06 04:00:14 helpers:70] Loss: 6.589085578918457
# [NeMo I 2020-02-06 04:00:14 helpers:71] training_batch_WER:  19.58%
# [NeMo I 2020-02-06 04:00:14 helpers:72] Prediction: rubout  a z d e four seven five seven
# [NeMo I 2020-02-06 04:00:14 helpers:73] Reference: rubout o g d e four seven five seven
# [NeMo I 2020-02-06 04:00:14 callbacks:211] Step time: 0.15142488479614258 seconds
# [NeMo I 2020-02-06 04:00:16 callbacks:179] Finished epoch 12 in 4.6180360317230225
# [NeMo I 2020-02-06 04:00:16 callbacks:172] Starting epoch 13
# [NeMo I 2020-02-06 04:00:18 callbacks:196] Step: 400
# [NeMo I 2020-02-06 04:00:18 helpers:70] Loss: 3.206146001815796
# [NeMo I 2020-02-06 04:00:18 helpers:71] training_batch_WER:  14.42%
# [NeMo I 2020-02-06 04:00:18 helpers:72] Prediction:  e n
# [NeMo I 2020-02-06 04:00:18 helpers:73] Reference: k e n
# [NeMo I 2020-02-06 04:00:18 callbacks:211] Step time: 0.16692042350769043 seconds
# [NeMo I 2020-02-06 04:00:21 callbacks:179] Finished epoch 13 in 4.615795850753784
# [NeMo I 2020-02-06 04:00:21 callbacks:172] Starting epoch 14
# [NeMo I 2020-02-06 04:00:22 callbacks:196] Step: 425
# [NeMo I 2020-02-06 04:00:22 helpers:70] Loss: 2.87601375579834
# [NeMo I 2020-02-06 04:00:22 helpers:71] training_batch_WER:  17.51%
# [NeMo I 2020-02-06 04:00:22 helpers:72] Prediction: four four oh six five
# [NeMo I 2020-02-06 04:00:22 helpers:73] Reference: four four oh six five
# [NeMo I 2020-02-06 04:00:22 callbacks:211] Step time: 0.15256309509277344 seconds
# [NeMo I 2020-02-06 04:00:25 callbacks:179] Finished epoch 14 in 4.635420799255371
# [NeMo I 2020-02-06 04:00:25 callbacks:172] Starting epoch 15
# [NeMo I 2020-02-06 04:00:26 callbacks:196] Step: 450
# [NeMo I 2020-02-06 04:00:26 helpers:70] Loss: 2.6229515075683594
# [NeMo I 2020-02-06 04:00:26 helpers:71] training_batch_WER:  17.93%
# [NeMo I 2020-02-06 04:00:26 helpers:72] Prediction: ye
# [NeMo I 2020-02-06 04:00:26 helpers:73] Reference: yes
# [NeMo I 2020-02-06 04:00:26 callbacks:211] Step time: 0.1541738510131836 seconds
# [NeMo I 2020-02-06 04:00:29 callbacks:196] Step: 475
# [NeMo I 2020-02-06 04:00:29 helpers:70] Loss: 4.077531814575195
# [NeMo I 2020-02-06 04:00:29 helpers:71] training_batch_WER:  17.93%
# [NeMo I 2020-02-06 04:00:29 helpers:72] Prediction: one five two one seven
# [NeMo I 2020-02-06 04:00:29 helpers:73] Reference: one five two one seven
# [NeMo I 2020-02-06 04:00:29 callbacks:211] Step time: 0.15845203399658203 seconds
# [NeMo I 2020-02-06 04:00:30 callbacks:179] Finished epoch 15 in 4.720238208770752
# [NeMo I 2020-02-06 04:00:30 callbacks:172] Starting epoch 16
# [NeMo I 2020-02-06 04:00:33 callbacks:196] Step: 500
# [NeMo I 2020-02-06 04:00:33 helpers:70] Loss: 2.7623865604400635
# [NeMo I 2020-02-06 04:00:33 helpers:71] training_batch_WER:  12.08%
# [NeMo I 2020-02-06 04:00:33 helpers:72] Prediction: ne two to two
# [NeMo I 2020-02-06 04:00:33 helpers:73] Reference: one two two two
# [NeMo I 2020-02-06 04:00:33 callbacks:211] Step time: 0.14835262298583984 seconds
# [NeMo I 2020-02-06 04:00:33 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 04:00:34 helpers:148] ==========>>>>>>Evaluation Loss: 15.0220365524292
# [NeMo I 2020-02-06 04:00:34 helpers:149] ==========>>>>>>Evaluation WER:  36.61%
# [NeMo I 2020-02-06 04:00:34 callbacks:411] Evaluation time: 0.2781984806060791 seconds
# [NeMo I 2020-02-06 04:00:35 callbacks:179] Finished epoch 16 in 4.9140965938568115
# [NeMo I 2020-02-06 04:00:35 callbacks:172] Starting epoch 17
# [NeMo I 2020-02-06 04:00:38 callbacks:196] Step: 525
# [NeMo I 2020-02-06 04:00:38 helpers:70] Loss: 2.366877555847168
# [NeMo I 2020-02-06 04:00:38 helpers:71] training_batch_WER:  13.86%
# [NeMo I 2020-02-06 04:00:38 helpers:72] Prediction: one five two one three
# [NeMo I 2020-02-06 04:00:38 helpers:73] Reference: one five two one three
# [NeMo I 2020-02-06 04:00:38 callbacks:211] Step time: 0.13531756401062012 seconds
# [NeMo I 2020-02-06 04:00:40 callbacks:179] Finished epoch 17 in 4.681416034698486
# [NeMo I 2020-02-06 04:00:40 callbacks:172] Starting epoch 18
# [NeMo I 2020-02-06 04:00:41 callbacks:196] Step: 550
# [NeMo I 2020-02-06 04:00:41 helpers:70] Loss: 4.901585102081299
# [NeMo I 2020-02-06 04:00:41 helpers:71] training_batch_WER:  24.14%
# [NeMo I 2020-02-06 04:00:41 helpers:72] Prediction: four eight four two
# [NeMo I 2020-02-06 04:00:41 helpers:73] Reference: four eight four two
# [NeMo I 2020-02-06 04:00:41 callbacks:211] Step time: 0.1538984775543213 seconds
# [NeMo I 2020-02-06 04:00:44 callbacks:179] Finished epoch 18 in 4.580342769622803
# [NeMo I 2020-02-06 04:00:44 callbacks:172] Starting epoch 19
# [NeMo I 2020-02-06 04:00:45 callbacks:196] Step: 575
# [NeMo I 2020-02-06 04:00:45 helpers:70] Loss: 1.2072174549102783
# [NeMo I 2020-02-06 04:00:45 helpers:71] training_batch_WER:  7.65%
# [NeMo I 2020-02-06 04:00:45 helpers:72] Prediction: no
# [NeMo I 2020-02-06 04:00:45 helpers:73] Reference: no
# [NeMo I 2020-02-06 04:00:45 callbacks:211] Step time: 0.13627934455871582 seconds
# [NeMo I 2020-02-06 04:00:49 callbacks:179] Finished epoch 19 in 4.563145875930786
# [NeMo I 2020-02-06 04:00:49 callbacks:172] Starting epoch 20
# [NeMo I 2020-02-06 04:00:49 callbacks:196] Step: 600
# [NeMo I 2020-02-06 04:00:49 helpers:70] Loss: 2.3645827770233154
# [NeMo I 2020-02-06 04:00:49 helpers:71] training_batch_WER:  13.33%
# [NeMo I 2020-02-06 04:00:49 helpers:72] Prediction: m a h o nn e y
# [NeMo I 2020-02-06 04:00:49 helpers:73] Reference: m a h o n e y
# [NeMo I 2020-02-06 04:00:49 callbacks:211] Step time: 0.14876008033752441 seconds
# [NeMo I 2020-02-06 04:00:53 callbacks:196] Step: 625
# [NeMo I 2020-02-06 04:00:53 helpers:70] Loss: 2.602267265319824
# [NeMo I 2020-02-06 04:00:53 helpers:71] training_batch_WER:  12.68%
# [NeMo I 2020-02-06 04:00:53 helpers:72] Prediction: nine four oh eight six
# [NeMo I 2020-02-06 04:00:53 helpers:73] Reference: nine four oh eight six
# [NeMo I 2020-02-06 04:00:53 callbacks:211] Step time: 0.15139389038085938 seconds
# [NeMo I 2020-02-06 04:00:53 callbacks:179] Finished epoch 20 in 4.655757427215576
# [NeMo I 2020-02-06 04:00:53 callbacks:172] Starting epoch 21
# [NeMo I 2020-02-06 04:00:57 callbacks:196] Step: 650
# [NeMo I 2020-02-06 04:00:57 helpers:70] Loss: 1.9202790260314941
# [NeMo I 2020-02-06 04:00:57 helpers:71] training_batch_WER:  8.57%
# [NeMo I 2020-02-06 04:00:57 helpers:72] Prediction: b u r k s
# [NeMo I 2020-02-06 04:00:57 helpers:73] Reference: b u r k s
# [NeMo I 2020-02-06 04:00:57 callbacks:211] Step time: 0.1531052589416504 seconds
# [NeMo I 2020-02-06 04:00:58 callbacks:179] Finished epoch 21 in 4.63152003288269
# [NeMo I 2020-02-06 04:00:58 callbacks:172] Starting epoch 22
# [NeMo I 2020-02-06 04:01:01 callbacks:196] Step: 675
# [NeMo I 2020-02-06 04:01:01 helpers:70] Loss: 1.6840264797210693
# [NeMo I 2020-02-06 04:01:01 helpers:71] training_batch_WER:  10.99%
# [NeMo I 2020-02-06 04:01:01 helpers:72] Prediction: no
# [NeMo I 2020-02-06 04:01:01 helpers:73] Reference: no
# [NeMo I 2020-02-06 04:01:01 callbacks:211] Step time: 0.14877915382385254 seconds
# [NeMo I 2020-02-06 04:01:03 callbacks:179] Finished epoch 22 in 4.551983833312988
# [NeMo I 2020-02-06 04:01:03 callbacks:172] Starting epoch 23
# [NeMo I 2020-02-06 04:01:04 callbacks:196] Step: 700
# [NeMo I 2020-02-06 04:01:04 helpers:70] Loss: 2.0163021087646484
# [NeMo I 2020-02-06 04:01:04 helpers:71] training_batch_WER:  10.70%
# [NeMo I 2020-02-06 04:01:04 helpers:72] Prediction: enter four twenty one
# [NeMo I 2020-02-06 04:01:04 helpers:73] Reference: enter four twenty one
# [NeMo I 2020-02-06 04:01:04 callbacks:211] Step time: 0.15105104446411133 seconds
# [NeMo I 2020-02-06 04:01:07 callbacks:179] Finished epoch 23 in 4.635217189788818
# [NeMo I 2020-02-06 04:01:07 callbacks:172] Starting epoch 24
# [NeMo I 2020-02-06 04:01:08 callbacks:196] Step: 725
# [NeMo I 2020-02-06 04:01:08 helpers:70] Loss: 1.2047653198242188
# [NeMo I 2020-02-06 04:01:08 helpers:71] training_batch_WER:  7.47%
# [NeMo I 2020-02-06 04:01:08 helpers:72] Prediction: rubeout i t d k m four seventy one
# [NeMo I 2020-02-06 04:01:08 helpers:73] Reference: rubout i t d k m four seventy one
# [NeMo I 2020-02-06 04:01:08 callbacks:211] Step time: 0.15347933769226074 seconds
# [NeMo I 2020-02-06 04:01:12 callbacks:179] Finished epoch 24 in 4.61393404006958
# [NeMo I 2020-02-06 04:01:12 callbacks:172] Starting epoch 25
# [NeMo I 2020-02-06 04:01:12 callbacks:196] Step: 750
# [NeMo I 2020-02-06 04:01:12 helpers:70] Loss: 0.6131175756454468
# [NeMo I 2020-02-06 04:01:12 helpers:71] training_batch_WER:  3.23%
# [NeMo I 2020-02-06 04:01:12 helpers:72] Prediction: erase s s w z nine
# [NeMo I 2020-02-06 04:01:12 helpers:73] Reference: erase s s w z nine
# [NeMo I 2020-02-06 04:01:12 callbacks:211] Step time: 0.14821887016296387 seconds
# [NeMo I 2020-02-06 04:01:16 callbacks:196] Step: 775
# [NeMo I 2020-02-06 04:01:16 helpers:70] Loss: 1.4757463932037354
# [NeMo I 2020-02-06 04:01:16 helpers:71] training_batch_WER:  6.15%
# [NeMo I 2020-02-06 04:01:16 helpers:72] Prediction: two sixight four six five eight
# [NeMo I 2020-02-06 04:01:16 helpers:73] Reference: two six eight four six five eight
# [NeMo I 2020-02-06 04:01:16 callbacks:211] Step time: 0.1600635051727295 seconds
# [NeMo I 2020-02-06 04:01:17 callbacks:179] Finished epoch 25 in 4.606563568115234
# [NeMo I 2020-02-06 04:01:17 callbacks:172] Starting epoch 26
# [NeMo I 2020-02-06 04:01:20 callbacks:196] Step: 800
# [NeMo I 2020-02-06 04:01:20 helpers:70] Loss: 3.1610629558563232
# [NeMo I 2020-02-06 04:01:20 helpers:71] training_batch_WER:  11.38%
# [NeMo I 2020-02-06 04:01:20 helpers:72] Prediction: c e nt r ea v e
# [NeMo I 2020-02-06 04:01:20 helpers:73] Reference: c e n t r e a v e
# [NeMo I 2020-02-06 04:01:20 callbacks:211] Step time: 0.15272998809814453 seconds
# [NeMo I 2020-02-06 04:01:21 callbacks:179] Finished epoch 26 in 4.580728054046631
# [NeMo I 2020-02-06 04:01:21 callbacks:172] Starting epoch 27
# [NeMo I 2020-02-06 04:01:24 callbacks:196] Step: 825
# [NeMo I 2020-02-06 04:01:24 helpers:70] Loss: 2.247678518295288
# [NeMo I 2020-02-06 04:01:24 helpers:71] training_batch_WER:  7.74%
# [NeMo I 2020-02-06 04:01:24 helpers:72] Prediction: repeat
# [NeMo I 2020-02-06 04:01:24 helpers:73] Reference: repeat
# [NeMo I 2020-02-06 04:01:24 callbacks:211] Step time: 0.1424565315246582 seconds
# [NeMo I 2020-02-06 04:01:26 callbacks:179] Finished epoch 27 in 4.584805965423584
# [NeMo I 2020-02-06 04:01:26 callbacks:172] Starting epoch 28
# [NeMo I 2020-02-06 04:01:28 callbacks:196] Step: 850
# [NeMo I 2020-02-06 04:01:28 helpers:70] Loss: 0.8797588348388672
# [NeMo I 2020-02-06 04:01:28 helpers:71] training_batch_WER:  4.69%
# [NeMo I 2020-02-06 04:01:28 helpers:72] Prediction: o r c h a r d p l a c e
# [NeMo I 2020-02-06 04:01:28 helpers:73] Reference: o r c h a r d p l a c e
# [NeMo I 2020-02-06 04:01:28 callbacks:211] Step time: 0.15037965774536133 seconds
# [NeMo I 2020-02-06 04:01:30 callbacks:179] Finished epoch 28 in 4.654595136642456
# [NeMo I 2020-02-06 04:01:30 callbacks:172] Starting epoch 29
# [NeMo I 2020-02-06 04:01:31 callbacks:196] Step: 875
# [NeMo I 2020-02-06 04:01:31 helpers:70] Loss: 2.680804491043091
# [NeMo I 2020-02-06 04:01:31 helpers:71] training_batch_WER:  11.30%
# [NeMo I 2020-02-06 04:01:31 helpers:72] Prediction: may ninth sixty two
# [NeMo I 2020-02-06 04:01:31 helpers:73] Reference: may ninth sixty two
# [NeMo I 2020-02-06 04:01:31 callbacks:211] Step time: 0.1543126106262207 seconds
# [NeMo I 2020-02-06 04:01:35 callbacks:179] Finished epoch 29 in 4.690739631652832
# [NeMo I 2020-02-06 04:01:35 callbacks:172] Starting epoch 30
# [NeMo I 2020-02-06 04:01:35 callbacks:196] Step: 900
# [NeMo I 2020-02-06 04:01:35 helpers:70] Loss: 1.2680017948150635
# [NeMo I 2020-02-06 04:01:35 helpers:71] training_batch_WER:  5.24%
# [NeMo I 2020-02-06 04:01:35 helpers:72] Prediction: one housand
# [NeMo I 2020-02-06 04:01:35 helpers:73] Reference: one thousand
# [NeMo I 2020-02-06 04:01:35 callbacks:211] Step time: 0.1515040397644043 seconds
# [NeMo I 2020-02-06 04:01:39 callbacks:196] Step: 925
# [NeMo I 2020-02-06 04:01:39 helpers:70] Loss: 1.2948137521743774
# [NeMo I 2020-02-06 04:01:39 helpers:71] training_batch_WER:  8.33%
# [NeMo I 2020-02-06 04:01:39 helpers:72] Prediction: f i an d l e y d r i v
# [NeMo I 2020-02-06 04:01:39 helpers:73] Reference: f i n d l e y d r i v e
# [NeMo I 2020-02-06 04:01:39 callbacks:211] Step time: 0.1569657325744629 seconds
# [NeMo I 2020-02-06 04:01:40 callbacks:179] Finished epoch 30 in 4.669302225112915
# [NeMo I 2020-02-06 04:01:40 callbacks:172] Starting epoch 31
# [NeMo I 2020-02-06 04:01:43 callbacks:196] Step: 950
# [NeMo I 2020-02-06 04:01:43 helpers:70] Loss: 1.0588408708572388
# [NeMo I 2020-02-06 04:01:43 helpers:71] training_batch_WER:  6.99%
# [NeMo I 2020-02-06 04:01:43 helpers:72] Prediction: apil tthirtieth nineteen sixty nine
# [NeMo I 2020-02-06 04:01:43 helpers:73] Reference: april thirtieth nineteen sixty nine
# [NeMo I 2020-02-06 04:01:43 callbacks:211] Step time: 0.15151214599609375 seconds
# [NeMo I 2020-02-06 04:01:44 callbacks:179] Finished epoch 31 in 4.632368564605713
# [NeMo I 2020-02-06 04:01:44 callbacks:172] Starting epoch 32
# [NeMo I 2020-02-06 04:01:47 callbacks:196] Step: 975
# [NeMo I 2020-02-06 04:01:47 helpers:70] Loss: 1.0186127424240112
# [NeMo I 2020-02-06 04:01:47 helpers:71] training_batch_WER:  2.87%
# [NeMo I 2020-02-06 04:01:47 helpers:72] Prediction: five two seven
# [NeMo I 2020-02-06 04:01:47 helpers:73] Reference: five two seven
# [NeMo I 2020-02-06 04:01:47 callbacks:211] Step time: 0.1549389362335205 seconds
# [NeMo I 2020-02-06 04:01:49 callbacks:179] Finished epoch 32 in 4.635733604431152
# [NeMo I 2020-02-06 04:01:49 callbacks:172] Starting epoch 33
# [NeMo I 2020-02-06 04:01:51 callbacks:196] Step: 1000
# [NeMo I 2020-02-06 04:01:51 helpers:70] Loss: 0.836809515953064
# [NeMo I 2020-02-06 04:01:51 helpers:71] training_batch_WER:  3.59%
# [NeMo I 2020-02-06 04:01:51 helpers:72] Prediction: enter one nine
# [NeMo I 2020-02-06 04:01:51 helpers:73] Reference: enter one nine
# [NeMo I 2020-02-06 04:01:51 callbacks:211] Step time: 0.1458890438079834 seconds
# [NeMo I 2020-02-06 04:01:51 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 04:01:51 helpers:148] ==========>>>>>>Evaluation Loss: 14.954123497009277
# [NeMo I 2020-02-06 04:01:51 helpers:149] ==========>>>>>>Evaluation WER:  28.72%
# [NeMo I 2020-02-06 04:01:51 callbacks:411] Evaluation time: 0.28621530532836914 seconds
# [NeMo I 2020-02-06 04:01:51 callbacks:275] Saved checkpoint: ./an4_checkpoints/trainer-STEP-1000.pt
# [NeMo I 2020-02-06 04:01:54 callbacks:179] Finished epoch 33 in 4.997387170791626
# [NeMo I 2020-02-06 04:01:54 callbacks:172] Starting epoch 34
# [NeMo I 2020-02-06 04:01:55 callbacks:196] Step: 1025
# [NeMo I 2020-02-06 04:01:55 helpers:70] Loss: 0.5648304224014282
# [NeMo I 2020-02-06 04:01:55 helpers:71] training_batch_WER:  2.84%
# [NeMo I 2020-02-06 04:01:55 helpers:72] Prediction: five one one five m a r g a r e t
# [NeMo I 2020-02-06 04:01:55 helpers:73] Reference: five one one five m a r g a r e t
# [NeMo I 2020-02-06 04:01:55 callbacks:211] Step time: 0.15131425857543945 seconds
# [NeMo I 2020-02-06 04:01:59 callbacks:179] Finished epoch 34 in 4.622928142547607
# [NeMo I 2020-02-06 04:01:59 callbacks:172] Starting epoch 35
# [NeMo I 2020-02-06 04:01:59 callbacks:196] Step: 1050
# [NeMo I 2020-02-06 04:01:59 helpers:70] Loss: 0.9484171271324158
# [NeMo I 2020-02-06 04:01:59 helpers:71] training_batch_WER:  4.49%
# [NeMo I 2020-02-06 04:01:59 helpers:72] Prediction: d a n i e l
# [NeMo I 2020-02-06 04:01:59 helpers:73] Reference: d a n i e l
# [NeMo I 2020-02-06 04:01:59 callbacks:211] Step time: 0.14292550086975098 seconds
# [NeMo I 2020-02-06 04:02:03 callbacks:196] Step: 1075
# [NeMo I 2020-02-06 04:02:03 helpers:70] Loss: 1.6308166980743408
# [NeMo I 2020-02-06 04:02:03 helpers:71] training_batch_WER:  11.92%
# [NeMo I 2020-02-06 04:02:03 helpers:72] Prediction: p u x p i five
# [NeMo I 2020-02-06 04:02:03 helpers:73] Reference: p u x p i five
# [NeMo I 2020-02-06 04:02:03 callbacks:211] Step time: 0.13785696029663086 seconds
# [NeMo I 2020-02-06 04:02:03 callbacks:179] Finished epoch 35 in 4.575569152832031
# [NeMo I 2020-02-06 04:02:03 callbacks:172] Starting epoch 36
# [NeMo I 2020-02-06 04:02:07 callbacks:196] Step: 1100
# [NeMo I 2020-02-06 04:02:07 helpers:70] Loss: 0.8462852239608765
# [NeMo I 2020-02-06 04:02:07 helpers:71] training_batch_WER:  5.53%
# [NeMo I 2020-02-06 04:02:07 helpers:72] Prediction: d o n a l d
# [NeMo I 2020-02-06 04:02:07 helpers:73] Reference: d o n a l d
# [NeMo I 2020-02-06 04:02:07 callbacks:211] Step time: 0.15041780471801758 seconds
# [NeMo I 2020-02-06 04:02:08 callbacks:179] Finished epoch 36 in 4.659518718719482
# [NeMo I 2020-02-06 04:02:08 callbacks:172] Starting epoch 37
# [NeMo I 2020-02-06 04:02:10 callbacks:196] Step: 1125
# [NeMo I 2020-02-06 04:02:10 helpers:70] Loss: 1.3864641189575195
# [NeMo I 2020-02-06 04:02:10 helpers:71] training_batch_WER:  6.35%
# [NeMo I 2020-02-06 04:02:10 helpers:72] Prediction: enter ninety eight twenty eight
# [NeMo I 2020-02-06 04:02:10 helpers:73] Reference: enter ninety eight twenty eight
# [NeMo I 2020-02-06 04:02:10 callbacks:211] Step time: 0.1415257453918457 seconds
# [NeMo I 2020-02-06 04:02:12 callbacks:179] Finished epoch 37 in 4.598342418670654
# [NeMo I 2020-02-06 04:02:12 callbacks:172] Starting epoch 38
# [NeMo I 2020-02-06 04:02:14 callbacks:196] Step: 1150
# [NeMo I 2020-02-06 04:02:14 helpers:70] Loss: 1.8038634061813354
# [NeMo I 2020-02-06 04:02:14 helpers:71] training_batch_WER:  2.73%
# [NeMo I 2020-02-06 04:02:14 helpers:72] Prediction: start
# [NeMo I 2020-02-06 04:02:14 helpers:73] Reference: start
# [NeMo I 2020-02-06 04:02:14 callbacks:211] Step time: 0.14617085456848145 seconds
# [NeMo I 2020-02-06 04:02:17 callbacks:179] Finished epoch 38 in 4.623946905136108
# [NeMo I 2020-02-06 04:02:17 callbacks:172] Starting epoch 39
# [NeMo I 2020-02-06 04:02:18 callbacks:196] Step: 1175
# [NeMo I 2020-02-06 04:02:18 helpers:70] Loss: 0.9392021298408508
# [NeMo I 2020-02-06 04:02:18 helpers:71] training_batch_WER:  5.14%
# [NeMo I 2020-02-06 04:02:18 helpers:72] Prediction: two nine six six two
# [NeMo I 2020-02-06 04:02:18 helpers:73] Reference: two nine six six two
# [NeMo I 2020-02-06 04:02:18 callbacks:211] Step time: 0.15794968605041504 seconds
# [NeMo I 2020-02-06 04:02:22 callbacks:179] Finished epoch 39 in 4.621100425720215
# [NeMo I 2020-02-06 04:02:22 callbacks:172] Starting epoch 40
# [NeMo I 2020-02-06 04:02:22 callbacks:196] Step: 1200
# [NeMo I 2020-02-06 04:02:22 helpers:70] Loss: 1.3857216835021973
# [NeMo I 2020-02-06 04:02:22 helpers:71] training_batch_WER:  6.34%
# [NeMo I 2020-02-06 04:02:22 helpers:72] Prediction: four four three six three one two
# [NeMo I 2020-02-06 04:02:22 helpers:73] Reference: four four three six three one two
# [NeMo I 2020-02-06 04:02:22 callbacks:211] Step time: 0.1529853343963623 seconds
# [NeMo I 2020-02-06 04:02:26 callbacks:196] Step: 1225
# [NeMo I 2020-02-06 04:02:26 helpers:70] Loss: 0.9098494052886963
# [NeMo I 2020-02-06 04:02:26 helpers:71] training_batch_WER:  4.62%
# [NeMo I 2020-02-06 04:02:26 helpers:72] Prediction: four four four seven
# [NeMo I 2020-02-06 04:02:26 helpers:73] Reference: four four four seven
# [NeMo I 2020-02-06 04:02:26 callbacks:211] Step time: 0.13762187957763672 seconds
# [NeMo I 2020-02-06 04:02:26 callbacks:179] Finished epoch 40 in 4.6005260944366455
# [NeMo I 2020-02-06 04:02:26 callbacks:172] Starting epoch 41
# [NeMo I 2020-02-06 04:02:30 callbacks:196] Step: 1250
# [NeMo I 2020-02-06 04:02:30 helpers:70] Loss: 0.44065940380096436
# [NeMo I 2020-02-06 04:02:30 helpers:71] training_batch_WER:  2.54%
# [NeMo I 2020-02-06 04:02:30 helpers:72] Prediction: a r a p a h o e
# [NeMo I 2020-02-06 04:02:30 helpers:73] Reference: a r a p a h o e
# [NeMo I 2020-02-06 04:02:30 callbacks:211] Step time: 0.1436161994934082 seconds
# [NeMo I 2020-02-06 04:02:31 callbacks:179] Finished epoch 41 in 4.619038343429565
# [NeMo I 2020-02-06 04:02:31 callbacks:172] Starting epoch 42
# [NeMo I 2020-02-06 04:02:33 callbacks:196] Step: 1275
# [NeMo I 2020-02-06 04:02:33 helpers:70] Loss: 0.4966343641281128
# [NeMo I 2020-02-06 04:02:33 helpers:71] training_batch_WER:  1.25%
# [NeMo I 2020-02-06 04:02:33 helpers:72] Prediction: fifty three forty two
# [NeMo I 2020-02-06 04:02:33 helpers:73] Reference: fifty three forty two
# [NeMo I 2020-02-06 04:02:33 callbacks:211] Step time: 0.1272904872894287 seconds
# [NeMo I 2020-02-06 04:02:36 callbacks:179] Finished epoch 42 in 4.6487650871276855
# [NeMo I 2020-02-06 04:02:36 callbacks:172] Starting epoch 43
# [NeMo I 2020-02-06 04:02:37 callbacks:196] Step: 1300
# [NeMo I 2020-02-06 04:02:37 helpers:70] Loss: 0.6735785007476807
# [NeMo I 2020-02-06 04:02:37 helpers:71] training_batch_WER:  3.79%
# [NeMo I 2020-02-06 04:02:37 helpers:72] Prediction: rubou y y f hx zero
# [NeMo I 2020-02-06 04:02:37 helpers:73] Reference: rubout y y f x zero
# [NeMo I 2020-02-06 04:02:37 callbacks:211] Step time: 0.13907909393310547 seconds
# [NeMo I 2020-02-06 04:02:40 callbacks:179] Finished epoch 43 in 4.6261632442474365
# [NeMo I 2020-02-06 04:02:40 callbacks:172] Starting epoch 44
# [NeMo I 2020-02-06 04:02:41 callbacks:196] Step: 1325
# [NeMo I 2020-02-06 04:02:41 helpers:70] Loss: 0.21529409289360046
# [NeMo I 2020-02-06 04:02:41 helpers:71] training_batch_WER:  1.10%
# [NeMo I 2020-02-06 04:02:41 helpers:72] Prediction: one five two one three
# [NeMo I 2020-02-06 04:02:41 helpers:73] Reference: one five two one three
# [NeMo I 2020-02-06 04:02:41 callbacks:211] Step time: 0.14428496360778809 seconds
# [NeMo I 2020-02-06 04:02:45 callbacks:179] Finished epoch 44 in 4.574478387832642
# [NeMo I 2020-02-06 04:02:45 callbacks:172] Starting epoch 45
# [NeMo I 2020-02-06 04:02:45 callbacks:196] Step: 1350
# [NeMo I 2020-02-06 04:02:45 helpers:70] Loss: 0.2566417157649994
# [NeMo I 2020-02-06 04:02:45 helpers:71] training_batch_WER:  1.70%
# [NeMo I 2020-02-06 04:02:45 helpers:72] Prediction: i v a r s o n
# [NeMo I 2020-02-06 04:02:45 helpers:73] Reference: i v a r s o n
# [NeMo I 2020-02-06 04:02:45 callbacks:211] Step time: 0.15325641632080078 seconds
# [NeMo I 2020-02-06 04:02:49 callbacks:196] Step: 1375
# [NeMo I 2020-02-06 04:02:49 helpers:70] Loss: 1.2166423797607422
# [NeMo I 2020-02-06 04:02:49 helpers:71] training_batch_WER:  5.62%
# [NeMo I 2020-02-06 04:02:49 helpers:72] Prediction: x h b a c five three four four
# [NeMo I 2020-02-06 04:02:49 helpers:73] Reference: x h b a c five three four four
# [NeMo I 2020-02-06 04:02:49 callbacks:211] Step time: 0.14631152153015137 seconds
# [NeMo I 2020-02-06 04:02:49 callbacks:179] Finished epoch 45 in 4.662989139556885
# [NeMo I 2020-02-06 04:02:49 callbacks:172] Starting epoch 46
# [NeMo I 2020-02-06 04:02:53 callbacks:196] Step: 1400
# [NeMo I 2020-02-06 04:02:53 helpers:70] Loss: 1.506181001663208
# [NeMo I 2020-02-06 04:02:53 helpers:71] training_batch_WER:  5.49%
# [NeMo I 2020-02-06 04:02:53 helpers:72] Prediction: c r a f t o n
# [NeMo I 2020-02-06 04:02:53 helpers:73] Reference: c r a f t o n
# [NeMo I 2020-02-06 04:02:53 callbacks:211] Step time: 0.15352129936218262 seconds
# [NeMo I 2020-02-06 04:02:54 callbacks:179] Finished epoch 46 in 4.553999662399292
# [NeMo I 2020-02-06 04:02:54 callbacks:172] Starting epoch 47
# [NeMo I 2020-02-06 04:02:57 callbacks:196] Step: 1425
# [NeMo I 2020-02-06 04:02:57 helpers:70] Loss: 0.46317172050476074
# [NeMo I 2020-02-06 04:02:57 helpers:71] training_batch_WER:  1.94%
# [NeMo I 2020-02-06 04:02:57 helpers:72] Prediction: c a r n e g i  e
# [NeMo I 2020-02-06 04:02:57 helpers:73] Reference: c a r n e g i e
# [NeMo I 2020-02-06 04:02:57 callbacks:211] Step time: 0.1448674201965332 seconds
# [NeMo I 2020-02-06 04:02:59 callbacks:179] Finished epoch 47 in 4.607311487197876
# [NeMo I 2020-02-06 04:02:59 callbacks:172] Starting epoch 48
# [NeMo I 2020-02-06 04:03:00 callbacks:196] Step: 1450
# [NeMo I 2020-02-06 04:03:00 helpers:70] Loss: 1.3713113069534302
# [NeMo I 2020-02-06 04:03:00 helpers:71] training_batch_WER:  4.48%
# [NeMo I 2020-02-06 04:03:00 helpers:72] Prediction: one five two one three
# [NeMo I 2020-02-06 04:03:00 helpers:73] Reference: one five two one three
# [NeMo I 2020-02-06 04:03:00 callbacks:211] Step time: 0.14711332321166992 seconds
# [NeMo I 2020-02-06 04:03:03 callbacks:179] Finished epoch 48 in 4.587805986404419
# [NeMo I 2020-02-06 04:03:03 callbacks:172] Starting epoch 49
# [NeMo I 2020-02-06 04:03:04 callbacks:196] Step: 1475
# [NeMo I 2020-02-06 04:03:04 helpers:70] Loss: 0.5713043212890625
# [NeMo I 2020-02-06 04:03:04 helpers:71] training_batch_WER:  3.24%
# [NeMo I 2020-02-06 04:03:04 helpers:72] Prediction: f i l
# [NeMo I 2020-02-06 04:03:04 helpers:73] Reference: f i l
# [NeMo I 2020-02-06 04:03:04 callbacks:211] Step time: 0.15858149528503418 seconds
# [NeMo I 2020-02-06 04:03:08 callbacks:179] Finished epoch 49 in 4.666492223739624
# [NeMo I 2020-02-06 04:03:08 callbacks:172] Starting epoch 50
# [NeMo I 2020-02-06 04:03:08 callbacks:196] Step: 1500
# [NeMo I 2020-02-06 04:03:08 helpers:70] Loss: 1.5205599069595337
# [NeMo I 2020-02-06 04:03:08 helpers:71] training_batch_WER:  1.53%
# [NeMo I 2020-02-06 04:03:08 helpers:72] Prediction: stop
# [NeMo I 2020-02-06 04:03:08 helpers:73] Reference: stop
# [NeMo I 2020-02-06 04:03:08 callbacks:211] Step time: 0.15022754669189453 seconds
# [NeMo I 2020-02-06 04:03:08 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 04:03:08 helpers:148] ==========>>>>>>Evaluation Loss: 15.542990684509277
# [NeMo I 2020-02-06 04:03:08 helpers:149] ==========>>>>>>Evaluation WER:  29.24%
# [NeMo I 2020-02-06 04:03:08 callbacks:411] Evaluation time: 0.2960827350616455 seconds
# [NeMo I 2020-02-06 04:03:12 callbacks:196] Step: 1525
# [NeMo I 2020-02-06 04:03:12 helpers:70] Loss: 1.1670558452606201
# [NeMo I 2020-02-06 04:03:12 helpers:71] training_batch_WER:  6.99%
# [NeMo I 2020-02-06 04:03:12 helpers:72] Prediction: enter fifty one
# [NeMo I 2020-02-06 04:03:12 helpers:73] Reference: enter fifty one
# [NeMo I 2020-02-06 04:03:12 callbacks:211] Step time: 0.15158987045288086 seconds
# [NeMo I 2020-02-06 04:03:13 callbacks:179] Finished epoch 50 in 4.9015421867370605
# [NeMo I 2020-02-06 04:03:13 callbacks:172] Starting epoch 51
# [NeMo I 2020-02-06 04:03:16 callbacks:196] Step: 1550
# [NeMo I 2020-02-06 04:03:16 helpers:70] Loss: 0.2933649718761444
# [NeMo I 2020-02-06 04:03:16 helpers:71] training_batch_WER:  2.84%
# [NeMo I 2020-02-06 04:03:16 helpers:72] Prediction: c a r n e g i e
# [NeMo I 2020-02-06 04:03:16 helpers:73] Reference: c a r n e g i e
# [NeMo I 2020-02-06 04:03:16 callbacks:211] Step time: 0.1456007957458496 seconds
# [NeMo I 2020-02-06 04:03:17 callbacks:179] Finished epoch 51 in 4.581434726715088
# [NeMo I 2020-02-06 04:03:17 callbacks:172] Starting epoch 52
# [NeMo I 2020-02-06 04:03:20 callbacks:196] Step: 1575
# [NeMo I 2020-02-06 04:03:20 helpers:70] Loss: 1.2068111896514893
# [NeMo I 2020-02-06 04:03:20 helpers:71] training_batch_WER:  5.56%
# [NeMo I 2020-02-06 04:03:20 helpers:72] Prediction: b r a d f o  d w o o d s
# [NeMo I 2020-02-06 04:03:20 helpers:73] Reference: b r a d f o r d w o o d s
# [NeMo I 2020-02-06 04:03:20 callbacks:211] Step time: 0.14668774604797363 seconds
# [NeMo I 2020-02-06 04:03:22 callbacks:179] Finished epoch 52 in 4.672131299972534
# [NeMo I 2020-02-06 04:03:22 callbacks:172] Starting epoch 53
# [NeMo I 2020-02-06 04:03:24 callbacks:196] Step: 1600
# [NeMo I 2020-02-06 04:03:24 helpers:70] Loss: 0.44321808218955994
# [NeMo I 2020-02-06 04:03:24 helpers:71] training_batch_WER:  2.07%
# [NeMo I 2020-02-06 04:03:24 helpers:72] Prediction: two six eight four six seven eiht
# [NeMo I 2020-02-06 04:03:24 helpers:73] Reference: two six eight four six seven eight
# [NeMo I 2020-02-06 04:03:24 callbacks:211] Step time: 0.1469569206237793 seconds
# [NeMo I 2020-02-06 04:03:27 callbacks:179] Finished epoch 53 in 4.706854581832886
# [NeMo I 2020-02-06 04:03:27 callbacks:172] Starting epoch 54
# [NeMo I 2020-02-06 04:03:28 callbacks:196] Step: 1625
# [NeMo I 2020-02-06 04:03:28 helpers:70] Loss: 0.4094340205192566
# [NeMo I 2020-02-06 04:03:28 helpers:71] training_batch_WER:  3.07%
# [NeMo I 2020-02-06 04:03:28 helpers:72] Prediction: repeat
# [NeMo I 2020-02-06 04:03:28 helpers:73] Reference: repeat
# [NeMo I 2020-02-06 04:03:28 callbacks:211] Step time: 0.15495848655700684 seconds
# [NeMo I 2020-02-06 04:03:31 callbacks:179] Finished epoch 54 in 4.627681732177734
# [NeMo I 2020-02-06 04:03:31 callbacks:172] Starting epoch 55
# [NeMo I 2020-02-06 04:03:32 callbacks:196] Step: 1650
# [NeMo I 2020-02-06 04:03:32 helpers:70] Loss: 0.20761632919311523
# [NeMo I 2020-02-06 04:03:32 helpers:71] training_batch_WER:  1.05%
# [NeMo I 2020-02-06 04:03:32 helpers:72] Prediction: twenty two twenty six
# [NeMo I 2020-02-06 04:03:32 helpers:73] Reference: twenty two twenty six
# [NeMo I 2020-02-06 04:03:32 callbacks:211] Step time: 0.15021419525146484 seconds
# [NeMo I 2020-02-06 04:03:36 callbacks:196] Step: 1675
# [NeMo I 2020-02-06 04:03:36 helpers:70] Loss: 0.728852391242981
# [NeMo I 2020-02-06 04:03:36 helpers:71] training_batch_WER:  5.00%
# [NeMo I 2020-02-06 04:03:36 helpers:72] Prediction: foufour four eightfour
# [NeMo I 2020-02-06 04:03:36 helpers:73] Reference: four four four eight four
# [NeMo I 2020-02-06 04:03:36 callbacks:211] Step time: 0.1463618278503418 seconds
# [NeMo I 2020-02-06 04:03:36 callbacks:179] Finished epoch 55 in 4.688101768493652
# [NeMo I 2020-02-06 04:03:36 callbacks:172] Starting epoch 56
# [NeMo I 2020-02-06 04:03:39 callbacks:196] Step: 1700
# [NeMo I 2020-02-06 04:03:39 helpers:70] Loss: 0.8021387457847595
# [NeMo I 2020-02-06 04:03:39 helpers:71] training_batch_WER:  2.26%
# [NeMo I 2020-02-06 04:03:39 helpers:72] Prediction: four oh three
# [NeMo I 2020-02-06 04:03:39 helpers:73] Reference: four oh three
# [NeMo I 2020-02-06 04:03:39 callbacks:211] Step time: 0.14931416511535645 seconds
# [NeMo I 2020-02-06 04:03:41 callbacks:179] Finished epoch 56 in 4.668270587921143
# [NeMo I 2020-02-06 04:03:41 callbacks:172] Starting epoch 57
# [NeMo I 2020-02-06 04:03:43 callbacks:196] Step: 1725
# [NeMo I 2020-02-06 04:03:43 helpers:70] Loss: 1.2509695291519165
# [NeMo I 2020-02-06 04:03:43 helpers:71] training_batch_WER:  3.65%
# [NeMo I 2020-02-06 04:03:43 helpers:72] Prediction: g e  f
# [NeMo I 2020-02-06 04:03:43 helpers:73] Reference: j e f f
# [NeMo I 2020-02-06 04:03:43 callbacks:211] Step time: 0.1530473232269287 seconds
# [NeMo I 2020-02-06 04:03:45 callbacks:179] Finished epoch 57 in 4.599728584289551
# [NeMo I 2020-02-06 04:03:45 callbacks:172] Starting epoch 58
# [NeMo I 2020-02-06 04:03:47 callbacks:196] Step: 1750
# [NeMo I 2020-02-06 04:03:47 helpers:70] Loss: 0.3660675287246704
# [NeMo I 2020-02-06 04:03:47 helpers:71] training_batch_WER:  2.59%
# [NeMo I 2020-02-06 04:03:47 helpers:72] Prediction: p i t t s b u r g h
# [NeMo I 2020-02-06 04:03:47 helpers:73] Reference: p i t t s b u r g h
# [NeMo I 2020-02-06 04:03:47 callbacks:211] Step time: 0.15091371536254883 seconds
# [NeMo I 2020-02-06 04:03:50 callbacks:179] Finished epoch 58 in 4.644760608673096
# [NeMo I 2020-02-06 04:03:50 callbacks:172] Starting epoch 59
# [NeMo I 2020-02-06 04:03:51 callbacks:196] Step: 1775
# [NeMo I 2020-02-06 04:03:51 helpers:70] Loss: 0.6240836381912231
# [NeMo I 2020-02-06 04:03:51 helpers:71] training_batch_WER:  4.26%
# [NeMo I 2020-02-06 04:03:51 helpers:72] Prediction: v e c c h i
# [NeMo I 2020-02-06 04:03:51 helpers:73] Reference: v e c c h i
# [NeMo I 2020-02-06 04:03:51 callbacks:211] Step time: 0.1487133502960205 seconds
# [NeMo I 2020-02-06 04:03:55 callbacks:179] Finished epoch 59 in 4.635864734649658
# [NeMo I 2020-02-06 04:03:55 callbacks:172] Starting epoch 60
# [NeMo I 2020-02-06 04:03:55 callbacks:196] Step: 1800
# [NeMo I 2020-02-06 04:03:55 helpers:70] Loss: 0.5580689907073975
# [NeMo I 2020-02-06 04:03:55 helpers:71] training_batch_WER:  3.90%
# [NeMo I 2020-02-06 04:03:55 helpers:72] Prediction: b a i q w eight
# [NeMo I 2020-02-06 04:03:55 helpers:73] Reference: b a i q w eight
# [NeMo I 2020-02-06 04:03:55 callbacks:211] Step time: 0.151228666305542 seconds
# [NeMo I 2020-02-06 04:03:59 callbacks:196] Step: 1825
# [NeMo I 2020-02-06 04:03:59 helpers:70] Loss: 0.5096602439880371
# [NeMo I 2020-02-06 04:03:59 helpers:71] training_batch_WER:  5.56%
# [NeMo I 2020-02-06 04:03:59 helpers:72] Prediction: enter two five four six
# [NeMo I 2020-02-06 04:03:59 helpers:73] Reference: enter two five four six
# [NeMo I 2020-02-06 04:03:59 callbacks:211] Step time: 0.1312699317932129 seconds
# [NeMo I 2020-02-06 04:03:59 callbacks:179] Finished epoch 60 in 4.589154958724976
# [NeMo I 2020-02-06 04:03:59 callbacks:172] Starting epoch 61
# [NeMo I 2020-02-06 04:04:03 callbacks:196] Step: 1850
# [NeMo I 2020-02-06 04:04:03 helpers:70] Loss: 0.6647200584411621
# [NeMo I 2020-02-06 04:04:03 helpers:71] training_batch_WER:  3.06%
# [NeMo I 2020-02-06 04:04:03 helpers:72] Prediction: p i t t s b u r g h
# [NeMo I 2020-02-06 04:04:03 helpers:73] Reference: p i t t s b u r g h
# [NeMo I 2020-02-06 04:04:03 callbacks:211] Step time: 0.1525576114654541 seconds
# [NeMo I 2020-02-06 04:04:04 callbacks:179] Finished epoch 61 in 4.618046045303345
# [NeMo I 2020-02-06 04:04:04 callbacks:172] Starting epoch 62
# [NeMo I 2020-02-06 04:04:06 callbacks:196] Step: 1875
# [NeMo I 2020-02-06 04:04:06 helpers:70] Loss: 0.751394510269165
# [NeMo I 2020-02-06 04:04:06 helpers:71] training_batch_WER:  5.20%
# [NeMo I 2020-02-06 04:04:06 helpers:72] Prediction:  a i l zero
# [NeMo I 2020-02-06 04:04:06 helpers:73] Reference: a a i l zero
# [NeMo I 2020-02-06 04:04:06 callbacks:211] Step time: 0.15705275535583496 seconds
# [NeMo I 2020-02-06 04:04:09 callbacks:179] Finished epoch 62 in 4.697158098220825
# [NeMo I 2020-02-06 04:04:09 callbacks:172] Starting epoch 63
# [NeMo I 2020-02-06 04:04:10 callbacks:196] Step: 1900
# [NeMo I 2020-02-06 04:04:10 helpers:70] Loss: 0.36261337995529175
# [NeMo I 2020-02-06 04:04:10 helpers:71] training_batch_WER:  1.62%
# [NeMo I 2020-02-06 04:04:10 helpers:72] Prediction: five two five five five
# [NeMo I 2020-02-06 04:04:10 helpers:73] Reference: five two five five five
# [NeMo I 2020-02-06 04:04:10 callbacks:211] Step time: 0.15000343322753906 seconds
# [NeMo I 2020-02-06 04:04:13 callbacks:179] Finished epoch 63 in 4.5630176067352295
# [NeMo I 2020-02-06 04:04:13 callbacks:172] Starting epoch 64
# [NeMo I 2020-02-06 04:04:14 callbacks:196] Step: 1925
# [NeMo I 2020-02-06 04:04:14 helpers:70] Loss: 0.3264055550098419
# [NeMo I 2020-02-06 04:04:14 helpers:71] training_batch_WER:  1.04%
# [NeMo I 2020-02-06 04:04:14 helpers:72] Prediction: one five oh four four
# [NeMo I 2020-02-06 04:04:14 helpers:73] Reference: one five oh four four
# [NeMo I 2020-02-06 04:04:14 callbacks:211] Step time: 0.15297770500183105 seconds
# [NeMo I 2020-02-06 04:04:18 callbacks:179] Finished epoch 64 in 4.578203201293945
# [NeMo I 2020-02-06 04:04:18 callbacks:172] Starting epoch 65
# [NeMo I 2020-02-06 04:04:18 callbacks:196] Step: 1950
# [NeMo I 2020-02-06 04:04:18 helpers:70] Loss: 0.35793617367744446
# [NeMo I 2020-02-06 04:04:18 helpers:71] training_batch_WER:  1.89%
# [NeMo I 2020-02-06 04:04:18 helpers:72] Prediction: n h o t q two eight three
# [NeMo I 2020-02-06 04:04:18 helpers:73] Reference: n h o t q two eight three
# [NeMo I 2020-02-06 04:04:18 callbacks:211] Step time: 0.12746334075927734 seconds
# [NeMo I 2020-02-06 04:04:22 callbacks:196] Step: 1975
# [NeMo I 2020-02-06 04:04:22 helpers:70] Loss: 0.42999356985092163
# [NeMo I 2020-02-06 04:04:22 helpers:71] training_batch_WER:  2.75%
# [NeMo I 2020-02-06 04:04:22 helpers:72] Prediction: h a n d e r s o n
# [NeMo I 2020-02-06 04:04:22 helpers:73] Reference: h a n d e r s o n
# [NeMo I 2020-02-06 04:04:22 callbacks:211] Step time: 0.14727210998535156 seconds
# [NeMo I 2020-02-06 04:04:22 callbacks:179] Finished epoch 65 in 4.616799831390381
# [NeMo I 2020-02-06 04:04:22 callbacks:172] Starting epoch 66
# [NeMo I 2020-02-06 04:04:26 callbacks:196] Step: 2000
# [NeMo I 2020-02-06 04:04:26 helpers:70] Loss: 0.08581939339637756
# [NeMo I 2020-02-06 04:04:26 helpers:71] training_batch_WER:  0.00%
# [NeMo I 2020-02-06 04:04:26 helpers:72] Prediction: r u s k i n
# [NeMo I 2020-02-06 04:04:26 helpers:73] Reference: r u s k i n
# [NeMo I 2020-02-06 04:04:26 callbacks:211] Step time: 0.14147114753723145 seconds
# [NeMo I 2020-02-06 04:04:26 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 04:04:26 helpers:148] ==========>>>>>>Evaluation Loss: 16.067943572998047
# [NeMo I 2020-02-06 04:04:26 helpers:149] ==========>>>>>>Evaluation WER:  26.26%
# [NeMo I 2020-02-06 04:04:26 callbacks:411] Evaluation time: 0.3221704959869385 seconds
# [NeMo I 2020-02-06 04:04:26 callbacks:275] Saved checkpoint: ./an4_checkpoints/trainer-STEP-2000.pt
# [NeMo I 2020-02-06 04:04:27 callbacks:179] Finished epoch 66 in 5.07887864112854
# [NeMo I 2020-02-06 04:04:27 callbacks:172] Starting epoch 67
# [NeMo I 2020-02-06 04:04:30 callbacks:196] Step: 2025
# [NeMo I 2020-02-06 04:04:30 helpers:70] Loss: 0.44194215536117554
# [NeMo I 2020-02-06 04:04:30 helpers:71] training_batch_WER:  0.56%
# [NeMo I 2020-02-06 04:04:30 helpers:72] Prediction: rubout f m q  n h three seventy
# [NeMo I 2020-02-06 04:04:30 helpers:73] Reference: rubout f m q n h three seventy
# [NeMo I 2020-02-06 04:04:30 callbacks:211] Step time: 0.15843462944030762 seconds
# [NeMo I 2020-02-06 04:04:32 callbacks:179] Finished epoch 67 in 4.67688512802124
# [NeMo I 2020-02-06 04:04:32 callbacks:172] Starting epoch 68
# [NeMo I 2020-02-06 04:04:34 callbacks:196] Step: 2050
# [NeMo I 2020-02-06 04:04:34 helpers:70] Loss: 0.2554808557033539
# [NeMo I 2020-02-06 04:04:34 helpers:71] training_batch_WER:  0.57%
# [NeMo I 2020-02-06 04:04:34 helpers:72] Prediction: u m n y h six
# [NeMo I 2020-02-06 04:04:34 helpers:73] Reference: u m n y h six
# [NeMo I 2020-02-06 04:04:34 callbacks:211] Step time: 0.15201735496520996 seconds
# [NeMo I 2020-02-06 04:04:37 callbacks:179] Finished epoch 68 in 4.60951042175293
# [NeMo I 2020-02-06 04:04:37 callbacks:172] Starting epoch 69
# [NeMo I 2020-02-06 04:04:38 callbacks:196] Step: 2075
# [NeMo I 2020-02-06 04:04:38 helpers:70] Loss: 0.37591156363487244
# [NeMo I 2020-02-06 04:04:38 helpers:71] training_batch_WER:  1.43%
# [NeMo I 2020-02-06 04:04:38 helpers:72] Prediction: a s b u r y p l a c e
# [NeMo I 2020-02-06 04:04:38 helpers:73] Reference: a s b u r y p l a c e
# [NeMo I 2020-02-06 04:04:38 callbacks:211] Step time: 0.15755176544189453 seconds
# [NeMo I 2020-02-06 04:04:41 callbacks:179] Finished epoch 69 in 4.6472437381744385
# [NeMo I 2020-02-06 04:04:41 callbacks:172] Starting epoch 70
# [NeMo I 2020-02-06 04:04:42 callbacks:196] Step: 2100
# [NeMo I 2020-02-06 04:04:42 helpers:70] Loss: 0.32563239336013794
# [NeMo I 2020-02-06 04:04:42 helpers:71] training_batch_WER:  2.21%
# [NeMo I 2020-02-06 04:04:42 helpers:72] Prediction: s t e v e n
# [NeMo I 2020-02-06 04:04:42 helpers:73] Reference: s t e v e n
# [NeMo I 2020-02-06 04:04:42 callbacks:211] Step time: 0.153245210647583 seconds
# [NeMo I 2020-02-06 04:04:45 callbacks:196] Step: 2125
# [NeMo I 2020-02-06 04:04:45 helpers:70] Loss: 0.9472665190696716
# [NeMo I 2020-02-06 04:04:45 helpers:71] training_batch_WER:  4.14%
# [NeMo I 2020-02-06 04:04:45 helpers:72] Prediction: seven nine three five four two nine
# [NeMo I 2020-02-06 04:04:45 helpers:73] Reference: seven nine three five four two nine
# [NeMo I 2020-02-06 04:04:45 callbacks:211] Step time: 0.14908933639526367 seconds
# [NeMo I 2020-02-06 04:04:46 callbacks:179] Finished epoch 70 in 4.6385650634765625
# [NeMo I 2020-02-06 04:04:46 callbacks:172] Starting epoch 71
# ...
# [NeMo I 2020-02-06 04:05:09 callbacks:179] Finished epoch 75 in 4.64217734336853
# [NeMo I 2020-02-06 04:05:09 callbacks:172] Starting epoch 76
# [NeMo I 2020-02-06 04:05:12 callbacks:196] Step: 2300
# [NeMo I 2020-02-06 04:05:12 helpers:70] Loss: 0.24331128597259521
# [NeMo I 2020-02-06 04:05:12 helpers:71] training_batch_WER:  1.65%
# [NeMo I 2020-02-06 04:05:12 helpers:72] Prediction: one five one one six
# [NeMo I 2020-02-06 04:05:12 helpers:73] Reference: one five one one six
# [NeMo I 2020-02-06 04:05:12 callbacks:211] Step time: 0.14093995094299316 seconds
# [NeMo I 2020-02-06 04:05:14 callbacks:179] Finished epoch 76 in 4.601736068725586
# [NeMo I 2020-02-06 04:05:14 callbacks:172] Starting epoch 77
# [NeMo I 2020-02-06 04:05:16 callbacks:196] Step: 2325
# [NeMo I 2020-02-06 04:05:16 helpers:70] Loss: 0.406414270401001
# [NeMo I 2020-02-06 04:05:16 helpers:71] training_batch_WER:  2.04%
# [NeMo I 2020-02-06 04:05:16 helpers:72] Prediction: p i t t s b u r g h
# [NeMo I 2020-02-06 04:05:16 helpers:73] Reference: p i t t s b u r g h
# [NeMo I 2020-02-06 04:05:16 callbacks:211] Step time: 0.15150713920593262 seconds
# [NeMo I 2020-02-06 04:05:18 callbacks:179] Finished epoch 77 in 4.639905691146851
# [NeMo I 2020-02-06 04:05:18 callbacks:172] Starting epoch 78
# [NeMo I 2020-02-06 04:05:20 callbacks:196] Step: 2350
# [NeMo I 2020-02-06 04:05:20 helpers:70] Loss: 0.35792049765586853
# [NeMo I 2020-02-06 04:05:20 helpers:71] training_batch_WER:  2.72%
# [NeMo I 2020-02-06 04:05:20 helpers:72] Prediction: h a h l e four ninety one
# [NeMo I 2020-02-06 04:05:20 helpers:73] Reference: h a h l e four ninety one
# [NeMo I 2020-02-06 04:05:20 callbacks:211] Step time: 0.14218711853027344 seconds
# [NeMo I 2020-02-06 04:05:23 callbacks:179] Finished epoch 78 in 4.595995664596558
# [NeMo I 2020-02-06 04:05:23 callbacks:172] Starting epoch 79
# [NeMo I 2020-02-06 04:05:24 callbacks:196] Step: 2375
# [NeMo I 2020-02-06 04:05:24 helpers:70] Loss: 0.6728436350822449
# [NeMo I 2020-02-06 04:05:24 helpers:71] training_batch_WER:  3.19%
# [NeMo I 2020-02-06 04:05:24 helpers:72] Prediction: m g e four oh two
# [NeMo I 2020-02-06 04:05:24 helpers:73] Reference: m g e four oh two
# [NeMo I 2020-02-06 04:05:24 callbacks:211] Step time: 0.1425168514251709 seconds
# [NeMo I 2020-02-06 04:05:28 callbacks:179] Finished epoch 79 in 4.661853790283203
# [NeMo I 2020-02-06 04:05:28 callbacks:172] Starting epoch 80
# [NeMo I 2020-02-06 04:05:28 callbacks:196] Step: 2400
# [NeMo I 2020-02-06 04:05:28 helpers:70] Loss: 0.1310737133026123
# [NeMo I 2020-02-06 04:05:28 helpers:71] training_batch_WER:  1.16%
# [NeMo I 2020-02-06 04:05:28 helpers:72] Prediction: eleven nine sixty eight
# [NeMo I 2020-02-06 04:05:28 helpers:73] Reference: eleven nine sixty eight
# [NeMo I 2020-02-06 04:05:28 callbacks:211] Step time: 0.14632630348205566 seconds
# [NeMo I 2020-02-06 04:05:32 callbacks:196] Step: 2425
# [NeMo I 2020-02-06 04:05:32 helpers:70] Loss: 0.5304422378540039
# [NeMo I 2020-02-06 04:05:32 helpers:71] training_batch_WER:  1.94%
# [NeMo I 2020-02-06 04:05:32 helpers:72] Prediction:  g h
# [NeMo I 2020-02-06 04:05:32 helpers:73] Reference: p g h
# [NeMo I 2020-02-06 04:05:32 callbacks:211] Step time: 0.14568805694580078 seconds
# [NeMo I 2020-02-06 04:05:32 callbacks:179] Finished epoch 80 in 4.643336057662964
# [NeMo I 2020-02-06 04:05:32 callbacks:172] Starting epoch 81
# [NeMo I 2020-02-06 04:05:36 callbacks:196] Step: 2450
# [NeMo I 2020-02-06 04:05:36 helpers:70] Loss: 0.43719929456710815
# [NeMo I 2020-02-06 04:05:36 helpers:71] training_batch_WER:  2.69%
# [NeMo I 2020-02-06 04:05:36 helpers:72] Prediction: three four four
# [NeMo I 2020-02-06 04:05:36 helpers:73] Reference: three four four
# [NeMo I 2020-02-06 04:05:36 callbacks:211] Step time: 0.1484365463256836 seconds
# [NeMo I 2020-02-06 04:05:37 callbacks:179] Finished epoch 81 in 4.656255006790161
# [NeMo I 2020-02-06 04:05:37 callbacks:172] Starting epoch 82
# [NeMo I 2020-02-06 04:05:39 callbacks:196] Step: 2475
# [NeMo I 2020-02-06 04:05:39 helpers:70] Loss: 0.24315911531448364
# [NeMo I 2020-02-06 04:05:39 helpers:71] training_batch_WER:  1.19%
# [NeMo I 2020-02-06 04:05:39 helpers:72] Prediction: seven seventeen fifty seven
# [NeMo I 2020-02-06 04:05:39 helpers:73] Reference: seven seventeen fifty seven
# [NeMo I 2020-02-06 04:05:39 callbacks:211] Step time: 0.14419198036193848 seconds
# [NeMo I 2020-02-06 04:05:42 callbacks:179] Finished epoch 82 in 4.652736663818359
# [NeMo I 2020-02-06 04:05:42 callbacks:172] Starting epoch 83
# [NeMo I 2020-02-06 04:05:43 callbacks:196] Step: 2500
# [NeMo I 2020-02-06 04:05:43 helpers:70] Loss: 0.5942509770393372
# [NeMo I 2020-02-06 04:05:43 helpers:71] training_batch_WER:  1.05%
# [NeMo I 2020-02-06 04:05:43 helpers:72] Prediction: rubout j b x r z nine twenty
# [NeMo I 2020-02-06 04:05:43 helpers:73] Reference: rubout j b x r z nine twenty
# [NeMo I 2020-02-06 04:05:43 callbacks:211] Step time: 0.15193963050842285 seconds
# [NeMo I 2020-02-06 04:05:43 callbacks:406] Doing Evaluation ..............................
# [NeMo I 2020-02-06 04:05:44 helpers:148] ==========>>>>>>Evaluation Loss: 20.503820419311523
# [NeMo I 2020-02-06 04:05:44 helpers:149] ==========>>>>>>Evaluation WER:  23.93%
# [NeMo I 2020-02-06 04:05:44 callbacks:411] Evaluation time: 0.28833866119384766 seconds
# [NeMo I 2020-02-06 04:05:47 callbacks:179] Finished epoch 83 in 4.9602930545806885
# [NeMo I 2020-02-06 04:05:47 callbacks:172] Starting epoch 84
# [NeMo I 2020-02-06 04:05:47 callbacks:196] Step: 2525
# [NeMo I 2020-02-06 04:05:47 helpers:70] Loss: 0.09714578092098236
# [NeMo I 2020-02-06 04:05:47 helpers:71] training_batch_WER:  0.56%
# [NeMo I 2020-02-06 04:05:47 helpers:72] Prediction: enter five
# [NeMo I 2020-02-06 04:05:47 helpers:73] Reference: enter five
# [NeMo I 2020-02-06 04:05:47 callbacks:211] Step time: 0.1463477611541748 seconds
# [NeMo I 2020-02-06 04:05:51 callbacks:179] Finished epoch 84 in 4.640983581542969
# [NeMo I 2020-02-06 04:05:51 callbacks:172] Starting epoch 85
# [NeMo I 2020-02-06 04:05:51 callbacks:196] Step: 2550
# [NeMo I 2020-02-06 04:05:51 helpers:70] Loss: 0.6757893562316895
# [NeMo I 2020-02-06 04:05:51 helpers:71] training_batch_WER:  3.98%
# [NeMo I 2020-02-06 04:05:51 helpers:72] Prediction: enter sixty
# [NeMo I 2020-02-06 04:05:51 helpers:73] Reference: enter sixty
# [NeMo I 2020-02-06 04:05:51 callbacks:211] Step time: 0.14046907424926758 seconds
# [NeMo I 2020-02-06 04:05:55 callbacks:196] Step: 2575
# [NeMo I 2020-02-06 04:05:55 helpers:70] Loss: 0.30152347683906555
# [NeMo I 2020-02-06 04:05:55 helpers:71] training_batch_WER:  1.91%
# [NeMo I 2020-02-06 04:05:55 helpers:72] Prediction: erase b m e e three five two
# [NeMo I 2020-02-06 04:05:55 helpers:73] Reference: erase b m e e three five two
# [NeMo I 2020-02-06 04:05:55 callbacks:211] Step time: 0.150054931640625 seconds
# [NeMo I 2020-02-06 04:05:56 callbacks:179] Finished epoch 85 in 4.672252655029297
# [NeMo I 2020-02-06 04:05:56 callbacks:172] Starting epoch 86
# [NeMo I 2020-02-06 04:05:59 callbacks:196] Step: 2600
# [NeMo I 2020-02-06 04:05:59 helpers:70] Loss: 0.1530875414609909
# [NeMo I 2020-02-06 04:05:59 helpers:71] training_batch_WER:  1.00%
# [NeMo I 2020-02-06 04:05:59 helpers:72] Prediction: six eight three one five five eight
# [NeMo I 2020-02-06 04:05:59 helpers:73] Reference: six eight three one five five eight
# [NeMo I 2020-02-06 04:05:59 callbacks:211] Step time: 0.14040207862854004 seconds
# [NeMo I 2020-02-06 04:06:00 callbacks:179] Finished epoch 86 in 4.635076999664307
# [NeMo I 2020-02-06 04:06:00 callbacks:172] Starting epoch 87
# [NeMo I 2020-02-06 04:06:03 callbacks:196] Step: 2625
# [NeMo I 2020-02-06 04:06:03 helpers:70] Loss: 0.08812923729419708
# [NeMo I 2020-02-06 04:06:03 helpers:71] training_batch_WER:  0.00%
# [NeMo I 2020-02-06 04:06:03 helpers:72] Prediction: c o n n e l l y
# [NeMo I 2020-02-06 04:06:03 helpers:73] Reference: c o n n e l l y
# [NeMo I 2020-02-06 04:06:03 callbacks:211] Step time: 0.145552396774292 seconds
# [NeMo I 2020-02-06 04:06:05 callbacks:179] Finished epoch 87 in 4.609526872634888
# [NeMo I 2020-02-06 04:06:05 callbacks:172] Starting epoch 88
# [NeMo I 2020-02-06 04:06:07 callbacks:196] Step: 2650
# [NeMo I 2020-02-06 04:06:07 helpers:70] Loss: 0.14299814403057098
# [NeMo I 2020-02-06 04:06:07 helpers:71] training_batch_WER:  0.43%
# [NeMo I 2020-02-06 04:06:07 helpers:72] Prediction: thirty one j a n u a r y one nine seven zero
# [NeMo I 2020-02-06 04:06:07 helpers:73] Reference: thirty one j a n u a r y one nine seven zero
# [NeMo I 2020-02-06 04:06:07 callbacks:211] Step time: 0.14935064315795898 seconds
# [NeMo I 2020-02-06 04:06:10 callbacks:179] Finished epoch 88 in 4.778923988342285
# [NeMo I 2020-02-06 04:06:10 callbacks:172] Starting epoch 89
# [NeMo I 2020-02-06 04:06:11 callbacks:196] Step: 2675
# [NeMo I 2020-02-06 04:06:11 helpers:70] Loss: 0.6398906707763672
# [NeMo I 2020-02-06 04:06:11 helpers:71] training_batch_WER:  0.94%
# [NeMo I 2020-02-06 04:06:11 helpers:72] Prediction: enter seven
# [NeMo I 2020-02-06 04:06:11 helpers:73] Reference: enter seven
# [NeMo I 2020-02-06 04:06:11 callbacks:211] Step time: 0.15349125862121582 seconds
# [NeMo I 2020-02-06 04:06:15 callbacks:179] Finished epoch 89 in 4.6652045249938965
# [NeMo I 2020-02-06 04:06:15 callbacks:172] Starting epoch 90
# [NeMo I 2020-02-06 04:06:15 callbacks:196] Step: 2700
# [NeMo I 2020-02-06 04:06:15 helpers:70] Loss: 0.16877137124538422
# [NeMo I 2020-02-06 04:06:15 helpers:71] training_batch_WER:  2.29%
# [NeMo I 2020-02-06 04:06:15 helpers:72] Prediction: j c h e q fifty eight thousand nine thirty nine
# [NeMo I 2020-02-06 04:06:15 helpers:73] Reference: j c h e q fifty eight thousand nine thirty nine
# [NeMo I 2020-02-06 04:06:15 callbacks:211] Step time: 0.15514731407165527 seconds
# [NeMo I 2020-02-06 04:06:19 callbacks:196] Step: 2725
# [NeMo I 2020-02-06 04:06:19 helpers:70] Loss: 0.0716138556599617
# [NeMo I 2020-02-06 04:06:19 helpers:71] training_batch_WER:  1.13%
# [NeMo I 2020-02-06 04:06:19 helpers:72] Prediction: two fifteen sixty two
# [NeMo I 2020-02-06 04:06:19 helpers:73] Reference: two fifteen sixty two
# [NeMo I 2020-02-06 04:06:19 callbacks:211] Step time: 0.15604066848754883 seconds
# [NeMo I 2020-02-06 04:06:19 callbacks:179] Finished epoch 90 in 4.678227424621582
# [NeMo I 2020-02-06 04:06:19 callbacks:172] Starting epoch 91
# [NeMo I 2020-02-06 04:06:22 callbacks:196] Step: 2750
# [NeMo I 2020-02-06 04:06:22 helpers:70] Loss: 0.41529369354248047
# [NeMo I 2020-02-06 04:06:22 helpers:71] training_batch_WER:  2.61%
# [NeMo I 2020-02-06 04:06:22 helpers:72] Prediction: start
# [NeMo I 2020-02-06 04:06:22 helpers:73] Reference: start
# [NeMo I 2020-02-06 04:06:22 callbacks:211] Step time: 0.14972686767578125 seconds
# [NeMo I 2020-02-06 04:06:24 callbacks:179] Finished epoch 91 in 4.5832343101501465
# [NeMo I 2020-02-06 04:06:24 callbacks:172] Starting epoch 92
# [NeMo I 2020-02-06 04:06:26 callbacks:196] Step: 2775
# [NeMo I 2020-02-06 04:06:26 helpers:70] Loss: 0.29505011439323425
# [NeMo I 2020-02-06 04:06:26 helpers:71] training_batch_WER:  1.64%
# [NeMo I 2020-02-06 04:06:26 helpers:72] Prediction: repeat
# [NeMo I 2020-02-06 04:06:26 helpers:73] Reference: repeat
# [NeMo I 2020-02-06 04:06:26 callbacks:211] Step time: 0.15619707107543945 seconds
# [NeMo I 2020-02-06 04:06:29 callbacks:179] Finished epoch 92 in 4.739161014556885
# [NeMo I 2020-02-06 04:06:29 callbacks:172] Starting epoch 93
# [NeMo I 2020-02-06 04:06:30 callbacks:196] Step: 2800
# [NeMo I 2020-02-06 04:06:30 helpers:70] Loss: 0.26874756813049316
# [NeMo I 2020-02-06 04:06:30 helpers:71] training_batch_WER:  0.53%
# [NeMo I 2020-02-06 04:06:30 helpers:72] Prediction: m a s o n
# [NeMo I 2020-02-06 04:06:30 helpers:73] Reference: m a s o n
# [NeMo I 2020-02-06 04:06:30 callbacks:211] Step time: 0.1574249267578125 seconds
# [NeMo I 2020-02-06 04:06:33 callbacks:179] Finished epoch 93 in 4.711772441864014
# [NeMo I 2020-02-06 04:06:33 callbacks:172] Starting epoch 94
# [NeMo I 2020-02-06 04:06:34 callbacks:196] Step: 2825
# [NeMo I 2020-02-06 04:06:34 helpers:70] Loss: 0.27934786677360535
# [NeMo I 2020-02-06 04:06:34 helpers:71] training_batch_WER:  0.53%
# [NeMo I 2020-02-06 04:06:34 helpers:72] Prediction: one five two one seven
# [NeMo I 2020-02-06 04:06:34 helpers:73] Reference: one five two one seven
# [NeMo I 2020-02-06 04:06:34 callbacks:211] Step time: 0.15372014045715332 seconds
# [NeMo I 2020-02-06 04:06:38 callbacks:179] Finished epoch 94 in 4.6652891635894775
# [NeMo I 2020-02-06 04:06:38 callbacks:172] Starting epoch 95
# [NeMo I 2020-02-06 04:06:38 callbacks:196] Step: 2850
# [NeMo I 2020-02-06 04:06:38 helpers:70] Loss: 0.22136886417865753
# [NeMo I 2020-02-06 04:06:38 helpers:71] training_batch_WER:  1.46%
# [NeMo I 2020-02-06 04:06:38 helpers:72] Prediction: b r i a n
# [NeMo I 2020-02-06 04:06:38 helpers:73] Reference: b r i a n
# [NeMo I 2020-02-06 04:06:38 callbacks:211] Step time: 0.15416407585144043 seconds
# [NeMo I 2020-02-06 04:06:42 callbacks:196] Step: 2875
# [NeMo I 2020-02-06 04:06:42 helpers:70] Loss: 1.3359230756759644
# [NeMo I 2020-02-06 04:06:42 helpers:71] training_batch_WER:  7.26%
# [NeMo I 2020-02-06 04:06:42 helpers:72] Prediction: june eleventh nineteen sixty seven
# [NeMo I 2020-02-06 04:06:42 helpers:73] Reference: june eleventh nineteen sixty seven
# [NeMo I 2020-02-06 04:06:42 callbacks:211] Step time: 0.15286612510681152 seconds
# [NeMo I 2020-02-06 04:06:43 callbacks:179] Finished epoch 95 in 4.696691274642944
# [NeMo I 2020-02-06 04:06:43 callbacks:172] Starting epoch 96
# [NeMo I 2020-02-06 04:06:46 callbacks:196] Step: 2900
# [NeMo I 2020-02-06 04:06:46 helpers:70] Loss: 0.4501112699508667
# [NeMo I 2020-02-06 04:06:46 helpers:71] training_batch_WER:  2.14%
# [NeMo I 2020-02-06 04:06:46 helpers:72] Prediction: two six eight three oh five four
# [NeMo I 2020-02-06 04:06:46 helpers:73] Reference: two six eight three oh five four
# [NeMo I 2020-02-06 04:06:46 callbacks:211] Step time: 0.16042327880859375 seconds
# [NeMo I 2020-02-06 04:06:47 callbacks:179] Finished epoch 96 in 4.637523174285889
# [NeMo I 2020-02-06 04:06:47 callbacks:172] Starting epoch 97
# [NeMo I 2020-02-06 04:06:50 callbacks:196] Step: 2925
# [NeMo I 2020-02-06 04:06:50 helpers:70] Loss: 1.0610589981079102
# [NeMo I 2020-02-06 04:06:50 helpers:71] training_batch_WER:  3.24%
# [NeMo I 2020-02-06 04:06:50 helpers:72] Prediction: start
# [NeMo I 2020-02-06 04:06:50 helpers:73] Reference: start
# [NeMo I 2020-02-06 04:06:50 callbacks:211] Step time: 0.14698004722595215 seconds
# [NeMo I 2020-02-06 04:06:52 callbacks:179] Finished epoch 97 in 4.649251222610474
# [NeMo I 2020-02-06 04:06:52 callbacks:172] Starting epoch 98
# [NeMo I 2020-02-06 04:06:54 callbacks:196] Step: 2950
# [NeMo I 2020-02-06 04:06:54 helpers:70] Loss: 0.08859661966562271
# [NeMo I 2020-02-06 04:06:54 helpers:71] training_batch_WER:  0.00%
# [NeMo I 2020-02-06 04:06:54 helpers:72] Prediction: erase z y g n p eight hundred and twenty three
# [NeMo I 2020-02-06 04:06:54 helpers:73] Reference: erase z y g n p eight hundred and twenty three
# [NeMo I 2020-02-06 04:06:54 callbacks:211] Step time: 0.14641952514648438 seconds
# [NeMo I 2020-02-06 04:06:57 callbacks:179] Finished epoch 98 in 4.671966791152954
# [NeMo I 2020-02-06 04:06:57 callbacks:172] Starting epoch 99
# [NeMo I 2020-02-06 04:06:58 callbacks:196] Step: 2975
# [NeMo I 2020-02-06 04:06:58 helpers:70] Loss: 0.18497304618358612
# [NeMo I 2020-02-06 04:06:58 helpers:71] training_batch_WER:  1.20%
# [NeMo I 2020-02-06 04:06:58 helpers:72] Prediction: g l e n n
# [NeMo I 2020-02-06 04:06:58 helpers:73] Reference: g l e n n
# [NeMo I 2020-02-06 04:06:58 callbacks:211] Step time: 0.1546003818511963 seconds
# [NeMo I 2020-02-06 04:07:01 callbacks:179] Finished epoch 99 in 4.597487211227417
# [NeMo I 2020-02-06 04:07:01 callbacks:168] Done in 466.0293724536896
# [NeMo I 2020-02-06 04:07:01 callbacks:416] Final Evaluation ..............................
# [NeMo I 2020-02-06 04:07:02 helpers:148] ==========>>>>>>Evaluation Loss: 17.984556198120117
# [NeMo I 2020-02-06 04:07:02 helpers:149] ==========>>>>>>Evaluation WER:  23.03%
# [NeMo I 2020-02-06 04:07:02 callbacks:421] Evaluation time: 0.297227144241333 seconds
# [NeMo I 2020-02-06 04:07:02 callbacks:275] Saved checkpoint: ./an4_checkpoints/trainer-STEP-3000.pt

# %% [markdown]
# There we go! We've put together a full training pipeline for the model and trained it for 100 epochs.
#
# ### Inference
#
# What if we have a trained model that we **just want to run inference** on?
#
# In that case, we just need to instantiate and link up the modules needed for the evaluation DAG (same procedure as before), and then run `infer` to get the results. Let's see what performing inference with our last checkpoint would look like.

# %%
# --- Inference Only --- #

# We've already built the inference DAG above, so all we need is to call infer().
evaluated_tensors = neural_factory.infer(
    # These are the tensors we want to get from the model.
    tensors=[loss_test, preds_test, transcript_test, transcript_len_test],
    # checkpoint_dir specifies where the model params are loaded from.
    checkpoint_dir=(data_dir+'/an4_checkpoints')
    )

# Process the results to get WER
from nemo.collections.asr.helpers import word_error_rate, \
    post_process_predictions, post_process_transcripts

greedy_hypotheses = post_process_predictions(
    evaluated_tensors[1], labels)

references = post_process_transcripts(
    evaluated_tensors[2], evaluated_tensors[3], labels)

wer = word_error_rate(hypotheses=greedy_hypotheses, references=references)
print("*** Greedy WER: {:.2f} ***".format(wer * 100))
# Out:
# [NeMo I 2020-02-06 04:10:59 actions:1406] Restoring JasperEncoder from ./an4_checkpoints/JasperEncoder-STEP-3000.pt
# [NeMo I 2020-02-06 04:10:59 actions:1406] Restoring JasperDecoderForCTC from ./an4_checkpoints/JasperDecoderForCTC-STEP-3000.pt
# [NeMo I 2020-02-06 04:11:00 actions:719] Evaluating batch 0 out of 5
# [NeMo I 2020-02-06 04:11:00 actions:719] Evaluating batch 1 out of 5
# [NeMo I 2020-02-06 04:11:00 actions:719] Evaluating batch 2 out of 5
# [NeMo I 2020-02-06 04:11:00 actions:719] Evaluating batch 3 out of 5
# [NeMo I 2020-02-06 04:11:00 actions:719] Evaluating batch 4 out of 5
# *** Greedy WER: 23.29 ***

# %% [markdown]
# And that's it!

# %% [markdown]
# ## Model Improvements
#
# In this section, we'll briefly cover a few possibilities for improving an ASR model.
#
# ### Data Augmentation
#
# There exist several ASR data augmentation methods that can increase the size of our training set.
#
# For example, we can perform augmentation on the spectrograms by zeroing out specific frequency segments ("frequency masking") or time segments ("time masking") as described by [SpecAugment](https://arxiv.org/abs/1904.08779), or zero out rectangles on the spectrogram as in [Cutout](https://arxiv.org/pdf/1708.04552.pdf). In NeMo, we can do all three of these by simply adding in a `SpectrogramAugmentation` neural module. (As of now, it does not perform the time warping from the SpecAugment paper.)

# %%
# Create a SpectrogramAugmentation module
spectrogram_aug = nemo_asr.SpectrogramAugmentation(
    rect_masks=5, rect_time=120, rect_freq=50)

# Rearrange training DAG to use augmentation.
# The following code is mostly copy/pasted from the "Assemble Training DAG"
# section, with only one line added!
audio_signal, audio_signal_len, transcript, transcript_len = data_layer_train()

processed_signal, processed_signal_len = data_preprocessor(
    input_signal=audio_signal,
    length=audio_signal_len)

############## This is the only part that's changed! ##############
processed_signal_aug = spectrogram_aug(input_spec=processed_signal)

encoded, encoded_len = encoder(
    audio_signal=processed_signal_aug,  # Change this argument too
    length=processed_signal_len)
###################################################################

log_probs = decoder(encoder_output=encoded)
preds = greedy_decoder(log_probs=log_probs)  # Training predictions
loss = ctc_loss(
    log_probs=log_probs,
    targets=transcript,
    input_length=encoded_len,
    target_length=transcript_len)

# And then you can train as usual.

# %% [markdown]
# Another popular method of ASR data augmentation is speed perturbation, where the audio is sped up or slowed down slightly (e.g. 10% faster or slower), but that's currently not available as an option in NeMo yet.
#
# ### Using a Language Model
#
# Though a language model may not be especially suited to a task like AN4 where we have a bunch of letters being read in sequence, adding a language model for inference can the improve WER in most other ASR tasks, where the speech more closely matches normal patterns. We can use the probability distribution that a language model gives us to better match our predictions to sequences of words we would be more likely to see in the real world, such as correcting "keyboard and house" to "keyboard and mouse."
#
# If you have a language model that you'd like to use with a NeMo model, you can add a `BeamSearchDecoderWithLM` module to your DAG to get beam search predictions that use your language model file.
#
# ```python
# ### Instantiating the module ###
# beam_search_lm = nemo_asr.BeamSearchDecoderWithLM(
#     vocab=labels, beam_width=16,
#     alpha=2, beta=1.5,
#     lm_path="<path/to/language/model>"
# )
# ...
#
# ### In the DAG ###
# beam_predictions = beam_search_lm(log_probs=log_probs, lob_probs_len=encoded_len)
# ...
#
# ### During inference ###
# evaluated_tensors = neural_factory.infer(
#     tensors=[loss_test, preds_test, transcript_test, transcript_len_test, beam_predictions],
#     checkpoint_dir=(data_dir+'/an4_checkpoints')
# )
#
# # Get the top beam search hypothesis for each sample
# beam_hypotheses = []
# for mini_batch in evaluated_tensors[-1]:
#     for sample_hypotheses in mini_batch:
#         # sample_hypotheses is a set of (probability, prediction) pairs
#         beam_hypotheses.append(sample_hypotheses[0][1]) # Take top prediction
#
# references = post_process_transcripts(evaluated_tensors[1], labels=labels,
#                                       transcript_len_list=evaluated_tensors[2])
# wer = word_error_rate(hypotheses=beam_hypotheses, references=references)
#
# print("BEAM WER {:.2f}".format(wer*100))
# ```
#
# ### Fast Training
#
# Last but not least, we could simply speed up training our model! If you have the resources, you can speed up training by splitting the workload across multiple GPUs. Otherwise (or in addition), there's always mixed precision training, which allows you to increase your batch size.
#
# You can read more about both mixed precision and multi-GPU training using NeMo on [this page of the documentation](https://nvidia.github.io/NeMo/training.html).

# %% [markdown]
# ## Further reading/watching:
#
# That's all for now! If you'd like to learn more about the topics covered in this tutorial, here are some resources that may interest you:
# - [Stanford Lecture on ASR](https://www.youtube.com/watch?v=3MjIkWxXigM)
# - ["An Intuitive Explanation of Connectionist Temporal Classification"](https://towardsdatascience.com/intuitively-understanding-connectionist-temporal-classification-3797e43a86c)
# - [Explanation of CTC with Prefix Beam Search](https://medium.com/corti-ai/ctc-networks-and-language-models-prefix-beam-search-explained-c11d1ee23306)
# - [Listen Attend and Spell Paper (seq2seq ASR model)](https://arxiv.org/abs/1508.01211)
# - [Explanation of the mel spectrogram in more depth](https://towardsdatascience.com/getting-to-know-the-mel-spectrogram-31bca3e2d9d0)
# - [Jasper Paper](https://arxiv.org/abs/1904.03288)
# - [SpecAugment Paper](https://arxiv.org/abs/1904.08779)
# - [Explanation and visualization of SpecAugment](https://towardsdatascience.com/state-of-the-art-audio-data-augmentation-with-google-brains-specaugment-and-pytorch-d3d1a3ce291e)
# - [Cutout Paper](https://arxiv.org/pdf/1708.04552.pdf)
